# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import os

# file = open('data\kml\export.kml')
# xml_data = file.read()

# print(xml_data)

# file.close()

with open('data\kml\My Places_dec_9_22.kml') as file:

    xml_data = file.read()

    # print (xml_data)

# %%
# Initializing soup variable
soup = BeautifulSoup(xml_data, 'xml')

folders = soup.Document.Folder
list = soup.Document.Folder.find_all('Folder')
layers = soup.Document.Folder.Folder
polygons = soup.Document.Folder.Placemark.Polygon

## Create a dataframe to hold the data parsed from xml

df = pd.DataFrame(columns=['field', 'foul', 'fop'])

## Loop through the folders and extract the data


    
i = 0   

for i in range(len(list)):

    folders = list[i]
    field_name = folders.find('name').text
    # if folders.find_all('coordinates')[0] < folders.find_all('coordinates')[1]:
    #     # '''if foul is greater than fop, then foul is the second coordinate'''
    #     foul = folders.find_all('coordinates')[0].text
    #     fop = folders.find_all('coordinates')[1].text
    # else:
    #     foul = folders.find_all('coordinates')[1].text
    #     fop = folders.find_all('coordinates')[0].text

    foul = folders.find_all('coordinates')[0].text
    fop = folders.find_all('coordinates')[1].text
# print(foul)
# print(fop)
    row = {
        'field': field_name,
        'foul': foul,
        'fop': fop
    }

    i+=1

    df = df.append(row, ignore_index=True)


    
        


    

    # for polygon in layer.find_all('Placemark'):
        #     polygon_name = polygon.name.text
        #     print(polygon_name)
        #     for foul in polygon.find_all('SimpleData'):
        #         foul_name = foul.text
        #         print(foul_name)
        #         for fop in foul.find_all_next('SimpleData'):
        #             fop_name = fop.text
        #             print(fop_name)
        #             df = df.append({'name': name, 'layer': layer_name, 'polygon': polygon_name, 'foul': foul_name, 'fop': fop_name}, ignore_index=True)
# Out:
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\Justin\AppData\Local\Temp\ipykernel_7592\2690058346.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)

# %%
list[56]


# df['foul'] = df['foul'].str.replace(' ', ',')
df = df.replace(r'\n','', regex=True) 
df = df.replace(r'\t','', regex=True) 

df
# Out:
#                                          field  \
# 0                                 1. Beal City
# 1                                  1. Buchanan
# 2    1. Grosse Pointe Woods University Liggett
# 3                    10. Jackson Lumen Christi
# 4                      10. Kalamazoo Christian
# ..                                         ...
# 242                      Whitehall High School
# 243                  Whitmore Lake High School
# 244            Whittemore-Prescott High School
# 245                    Williamston High School
# 246                                        WMU
#
#                                                   foul  \
# 0    -84.9127615,43.6741539,0 -84.91275210000001,43...
# 1    -86.37097850000001,41.8239409,0 -86.3717456,41...
# 2    -82.90074989999999,42.4260393,0 -82.9002148,42...
# 3    -84.4602665,42.2219816,0 -84.4603248,42.222842...
# 4    -85.6134503,42.273406,0 -85.61346399999999,42....
# ..                                                 ...
# 242  -86.33278559999999,43.4045055,0 -86.3329868,43...
# 243  -83.7708313,42.3876304,0 -83.7700119,42.387014...
# 244  -83.8844484,44.2293306,0 -83.88555700000001,44...
# 245  -84.28086999999999,42.6987035,0 -84.2809585,42...
# 246  -85.6030368,42.2844309,0 -85.60341099999999,42...
#
#                                                    fop
# 0    -84.9127615,43.6741539,0 -84.9115486,43.674159...
# 1    -86.37097850000001,41.8239409,0 -86.3700572000...
# 2    -82.90074989999999,42.4260393,0 -82.8997751,42...
# 3    -84.4602665,42.2219816,0 -84.4591654,42.222017...
# 4    -85.6134503,42.273406,0 -85.6145228,42.2734125...
# ..                                                 ...
# 242  -86.33278559999999,43.4045055,0 -86.3316323,43...
# 243  -83.7708313,42.3876304,0 -83.7716762,42.387022...
# 244  -83.8844484,44.2293306,0 -83.8844618,44.230166...
# 245  -84.28086999999999,42.6987035,0 -84.2797126,42...
# 246  -85.6030368,42.2844309,0 -85.6018741,42.284731...
#
# [247 rows x 3 columns]

# %%
df['home_lat'] = df['foul'].str.split(',').str[0]
df['home_lon'] = df['foul'].str.split(',').str[1]
df
# df.to_csv('data/coord_export.csv', index=False)
# Out:
#                                          field  \
# 0                                 1. Beal City
# 1                                  1. Buchanan
# 2    1. Grosse Pointe Woods University Liggett
# 3                    10. Jackson Lumen Christi
# 4                      10. Kalamazoo Christian
# ..                                         ...
# 242                      Whitehall High School
# 243                  Whitmore Lake High School
# 244            Whittemore-Prescott High School
# 245                    Williamston High School
# 246                                        WMU
#
#                                                   foul  \
# 0    -84.9127615,43.6741539,0 -84.91275210000001,43...
# 1    -86.37097850000001,41.8239409,0 -86.3717456,41...
# 2    -82.90074989999999,42.4260393,0 -82.9002148,42...
# 3    -84.4602665,42.2219816,0 -84.4603248,42.222842...
# 4    -85.6134503,42.273406,0 -85.61346399999999,42....
# ..                                                 ...
# 242  -86.33278559999999,43.4045055,0 -86.3329868,43...
# 243  -83.7708313,42.3876304,0 -83.7700119,42.387014...
# 244  -83.8844484,44.2293306,0 -83.88555700000001,44...
# 245  -84.28086999999999,42.6987035,0 -84.2809585,42...
# 246  -85.6030368,42.2844309,0 -85.60341099999999,42...
#
#                                                    fop            home_lat  \
# 0    -84.9127615,43.6741539,0 -84.9115486,43.674159...         -84.9127615
# 1    -86.37097850000001,41.8239409,0 -86.3700572000...  -86.37097850000001
# 2    -82.90074989999999,42.4260393,0 -82.8997751,42...  -82.90074989999999
# 3    -84.4602665,42.2219816,0 -84.4591654,42.222017...         -84.4602665
# 4    -85.6134503,42.273406,0 -85.6145228,42.2734125...         -85.6134503
# ..                                                 ...                 ...
# 242  -86.33278559999999,43.4045055,0 -86.3316323,43...  -86.33278559999999
# 243  -83.7708313,42.3876304,0 -83.7716762,42.387022...         -83.7708313
# 244  -83.8844484,44.2293306,0 -83.8844618,44.230166...         -83.8844484
# 245  -84.28086999999999,42.6987035,0 -84.2797126,42...  -84.28086999999999
# 246  -85.6030368,42.2844309,0 -85.6018741,42.284731...         -85.6030368
#
#        home_lon
# 0    43.6741539
# 1    41.8239409
# 2    42.4260393
# 3    42.2219816
# 4     42.273406
# ..          ...
# 242  43.4045055
# 243  42.3876304
# 244  44.2293306
# 245  42.6987035
# 246  42.2844309
#
# [247 rows x 5 columns]

# %% [markdown]
# ### Working Above !!!

# %%
 ## Start messing around with calculating area from coordinate strings in dataframe

from area import area
from shapely import geometry

df['foul_area'] = df['foul'].apply(lambda x: area({'type': 'Polygon', 'coordinates': [[tuple(map(float, coord.split(','))) for coord in x.split()]]}))

df['fop_area'] = df['fop'].apply(lambda x: area({'type': 'Polygon', 'coordinates': [[tuple(map(float, coord.split(','))) for coord in x.split()]]}))

df['foul_ft'] = df['foul_area'].apply(lambda x: x*10.7639)
df['fop_ft'] = df['fop_area'].apply(lambda x: x*10.7639)


# df.to_csv('data/coord_export_after_calc.csv', index=False)

# %%
### Need to go through and drop duplicate rows

df = df.drop_duplicates(subset=['field'], keep='first')

df.to_csv('data/coord_export_after_calc.csv', index=False)

# %%
## Drop and rows with 0 because it screws up with geometry creator
df = df[(df != 0).all(1)]

### Make wrt strings for each polygon

df['foul_wkt'] = df['foul'].apply(lambda x: 'POLYGON( (' + x + '))')
df['fop_wkt'] = df['fop'].apply(lambda x: 'POLYGON( (' + x + '))')


df.head()
# Out:
#                                        field  \
# 0                               1. Beal City
# 1                                1. Buchanan
# 2  1. Grosse Pointe Woods University Liggett
# 3                  10. Jackson Lumen Christi
# 4                    10. Kalamazoo Christian
#
#                                                 foul  \
# 0  -84.9127615,43.6741539,0 -84.91275210000001,43...
# 1  -86.37097850000001,41.8239409,0 -86.3717456,41...
# 2  -82.90074989999999,42.4260393,0 -82.9002148,42...
# 3  -84.4602665,42.2219816,0 -84.4603248,42.222842...
# 4  -85.6134503,42.273406,0 -85.61346399999999,42....
#
#                                                  fop            home_lat  \
# 0  -84.9127615,43.6741539,0 -84.9115486,43.674159...         -84.9127615
# 1  -86.37097850000001,41.8239409,0 -86.3700572000...  -86.37097850000001
# 2  -82.90074989999999,42.4260393,0 -82.8997751,42...  -82.90074989999999
# 3  -84.4602665,42.2219816,0 -84.4591654,42.222017...         -84.4602665
# 4  -85.6134503,42.273406,0 -85.6145228,42.2734125...         -85.6134503
#
#      home_lon    foul_area     fop_area       foul_ft        fop_ft  \
# 0  43.6741539  2387.453607  8313.729768  25698.311886  89488.155852
# 1  41.8239409  2105.178908  8219.710003  22659.935253  88476.136505
# 2  42.4260393  2079.959303  7721.998424  22388.473941  83118.818831
# 3  42.2219816  1904.292945  8550.033157  20497.618836  92031.701897
# 4   42.273406  2223.572377  8566.263773  23934.310711  92206.406626
#
#                                             foul_wkt  \
# 0  POLYGON( (-84.9127615,43.6741539,0 -84.9127521...
# 1  POLYGON( (-86.37097850000001,41.8239409,0 -86....
# 2  POLYGON( (-82.90074989999999,42.4260393,0 -82....
# 3  POLYGON( (-84.4602665,42.2219816,0 -84.4603248...
# 4  POLYGON( (-85.6134503,42.273406,0 -85.61346399...
#
#                                              fop_wkt
# 0  POLYGON( (-84.9127615,43.6741539,0 -84.9115486...
# 1  POLYGON( (-86.37097850000001,41.8239409,0 -86....
# 2  POLYGON( (-82.90074989999999,42.4260393,0 -82....
# 3  POLYGON( (-84.4602665,42.2219816,0 -84.4591654...
# 4  POLYGON( (-85.6134503,42.273406,0 -85.6145228,...

# %%
df.head()

# df.info()
# Out:
#                                        field  \
# 0                               1. Beal City
# 1                                1. Buchanan
# 2  1. Grosse Pointe Woods University Liggett
# 3                  10. Jackson Lumen Christi
# 4                    10. Kalamazoo Christian
#
#                                                 foul  \
# 0  -84.9127615,43.6741539,0 -84.91275210000001,43...
# 1  -86.37097850000001,41.8239409,0 -86.3717456,41...
# 2  -82.90074989999999,42.4260393,0 -82.9002148,42...
# 3  -84.4602665,42.2219816,0 -84.4603248,42.222842...
# 4  -85.6134503,42.273406,0 -85.61346399999999,42....
#
#                                                  fop            home_lat  \
# 0  -84.9127615,43.6741539,0 -84.9115486,43.674159...         -84.9127615
# 1  -86.37097850000001,41.8239409,0 -86.3700572000...  -86.37097850000001
# 2  -82.90074989999999,42.4260393,0 -82.8997751,42...  -82.90074989999999
# 3  -84.4602665,42.2219816,0 -84.4591654,42.222017...         -84.4602665
# 4  -85.6134503,42.273406,0 -85.6145228,42.2734125...         -85.6134503
#
#      home_lon    foul_area     fop_area       foul_ft        fop_ft  \
# 0  43.6741539  2387.453607  8313.729768  25698.311886  89488.155852
# 1  41.8239409  2105.178908  8219.710003  22659.935253  88476.136505
# 2  42.4260393  2079.959303  7721.998424  22388.473941  83118.818831
# 3  42.2219816  1904.292945  8550.033157  20497.618836  92031.701897
# 4   42.273406  2223.572377  8566.263773  23934.310711  92206.406626
#
#                                             foul_wkt  \
# 0  POLYGON( (-84.9127615,43.6741539,0 -84.9127521...
# 1  POLYGON( (-86.37097850000001,41.8239409,0 -86....
# 2  POLYGON( (-82.90074989999999,42.4260393,0 -82....
# 3  POLYGON( (-84.4602665,42.2219816,0 -84.4603248...
# 4  POLYGON( (-85.6134503,42.273406,0 -85.61346399...
#
#                                              fop_wkt
# 0  POLYGON( (-84.9127615,43.6741539,0 -84.9115486...
# 1  POLYGON( (-86.37097850000001,41.8239409,0 -86....
# 2  POLYGON( (-82.90074989999999,42.4260393,0 -82....
# 3  POLYGON( (-84.4602665,42.2219816,0 -84.4591654...
# 4  POLYGON( (-85.6134503,42.273406,0 -85.6145228,...

# %% [markdown]
# ### Saturday. everything working to this point
#
# Next I need to get the wkt strings into shapely polygons
#
# # parse a pdf file to get enrollment data for all high schools

# %%
### CAN'T GET THIS TO WORK
# There is a problem with the underlying ghostscript module. Have tried a few different fixes but nothing has worked.
### moving on to trying to read PDF with tabula-py

# ### Install dependencies for pdf files

# ### Not working, problem with the ghostscript library that is needed. tried installing the 32 bit version (on lapto)
# import camelot
 
# # extract all the tables in the PDF file
# abc = camelot.read_pdf("data\school_info\HS_enrollment_mhsaa.pdf")   #address of file location
 
# # print the first table as Pandas DataFrame
# print(abc[0].df)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# c:\Users\Justin\Desktop\Project\BB_parks\working_parse_notebook.ipynb Cell 11 in <cell line: 7>()
#       <a href='vscode-notebook-cell:/c%3A/Users/Justin/Desktop/Project/BB_parks/working_parse_notebook.ipynb#X13sZmlsZQ%3D%3D?line=3'>4</a> import camelot
#       <a href='vscode-notebook-cell:/c%3A/Users/Justin/Desktop/Project/BB_parks/working_parse_notebook.ipynb#X13sZmlsZQ%3D%3D?line=5'>6</a> # extract all the tables in the PDF file
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Justin/Desktop/Project/BB_parks/working_parse_notebook.ipynb#X13sZmlsZQ%3D%3D?line=6'>7</a> abc = camelot.read_pdf("data\school_info\HS_enrollment_mhsaa.pdf")   #address of file location
#       <a href='vscode-notebook-cell:/c%3A/Users/Justin/Desktop/Project/BB_parks/working_parse_notebook.ipynb#X13sZmlsZQ%3D%3D?line=8'>9</a> # print the first table as Pandas DataFrame
#      <a href='vscode-notebook-cell:/c%3A/Users/Justin/Desktop/Project/BB_parks/working_parse_notebook.ipynb#X13sZmlsZQ%3D%3D?line=9'>10</a> print(abc[0].df)
#
# File c:\Users\Justin\anaconda3\lib\site-packages\camelot\io.py:113, in read_pdf(filepath, pages, password, flavor, suppress_stdout, layout_kwargs, **kwargs)
#     111 p = PDFHandler(filepath, pages=pages, password=password)
#     112 kwargs = remove_extra(kwargs, flavor=flavor)
# --> 113 tables = p.parse(
#     114     flavor=flavor,
#     115     suppress_stdout=suppress_stdout,
#     116     layout_kwargs=layout_kwargs,
#     117     **kwargs
#     118 )
#     119 return tables
#
# File c:\Users\Justin\anaconda3\lib\site-packages\camelot\handlers.py:176, in PDFHandler.parse(self, flavor, suppress_stdout, layout_kwargs, **kwargs)
#     174     parser = Lattice(**kwargs) if flavor == "lattice" else Stream(**kwargs)
#     175     for p in pages:
# --> 176         t = parser.extract_tables(
#     177             p, suppress_stdout=suppress_stdout, layout_kwargs=layout_kwargs
#     178         )
#     179         tables.extend(t)
#     180 return TableList(sorted(tables))
#
# File c:\Users\Justin\anaconda3\lib\site-packages\camelot\parsers\lattice.py:421, in Lattice.extract_tables(self, filename, suppress_stdout, layout_kwargs)
#     416         warnings.warn(
#     417             "No tables found on {}".format(os.path.basename(self.rootname))
#     418         )
#     419     return []
# --> 421 self.backend.convert(self.filename, self.imagename)
#     423 self._generate_table_bbox()
#     425 _tables = []
#
# File c:\Users\Justin\anaconda3\lib\site-packages\camelot\backends\ghostscript_backend.py:36, in GhostscriptBackend.convert(self, pdf_path, png_path, resolution)
#      30 if not self.installed():
#      31     raise OSError(
#      32         "Ghostscript is not installed. You can install it using the instructions"
#      33         " here: https://camelot-py.readthedocs.io/en/master/user/install-deps.html"
#      34     )
# ---> 36 import ghostscript
#      38 gs_command = [
#      39     "gs",
#      40     "-q",
#    (...)
#      45     pdf_path,
#      46 ]
#      47 ghostscript.Ghostscript(*gs_command)
#
# ModuleNotFoundError: No module named 'ghostscript'

# %% [markdown]
# ### Trying to read school enrolment pdf with tabula package

# %%
from tabula import read_pdf
from tabulate import tabulate
 
#reads table from pdf file
df = read_pdf("data\school_info\HS_enrollment_mhsaa.pdf",pages="all") #address of pdf file
print(tabulate(df))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File c:\Users\Justin\anaconda3\lib\site-packages\tabula\io.py:87, in _run(java_options, options, path, encoding)
#      86 try:
# ---> 87     result = subprocess.run(
#      88         args,
#      89         stdout=subprocess.PIPE,
#      90         stderr=subprocess.PIPE,
#      91         stdin=subprocess.DEVNULL,
#      92         check=True,
#      93     )
#      94     if result.stderr:
#
# File c:\Users\Justin\anaconda3\lib\subprocess.py:505, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     503     kwargs['stderr'] = PIPE
# --> 505 with Popen(*popenargs, **kwargs) as process:
#     506     try:
#
# File c:\Users\Justin\anaconda3\lib\subprocess.py:951, in Popen.__init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask)
#     948             self.stderr = io.TextIOWrapper(self.stderr,
#     949                     encoding=encoding, errors=errors)
# --> 951     self._execute_child(args, executable, preexec_fn, close_fds,
#     952                         pass_fds, cwd, env,
#     953                         startupinfo, creationflags, shell,
#     954                         p2cread, p2cwrite,
#     955                         c2pread, c2pwrite,
#     956                         errread, errwrite,
#     957                         restore_signals,
#     958                         gid, gids, uid, umask,
#     959                         start_new_session)
#     960 except:
#     961     # Cleanup if the child failed starting.
#
# File c:\Users\Justin\anaconda3\lib\subprocess.py:1420, in Popen._execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, unused_restore_signals, unused_gid, unused_gids, unused_uid, unused_umask, unused_start_new_session)
#    1419 try:
# -> 1420     hp, ht, pid, tid = _winapi.CreateProcess(executable, args,
#    1421                              # no special security
#    1422                              None, None,
#    1423                              int(not close_fds),
#    1424                              creationflags,
#    1425                              env,
#    1426                              cwd,
#    1427                              startupinfo)
#    1428 finally:
#    1429     # Child is launched. Close the parent's copy of those pipe
#    1430     # handles that only the child should have open.  You need
#    (...)
#    1433     # pipe will not close when the child process exits and the
#    1434     # ReadFile will hang.
#
# FileNotFoundError: [WinError 2] The system cannot find the file specified
#
# During handling of the above exception, another exception occurred:
#
# JavaNotFoundError                         Traceback (most recent call last)
# c:\Users\Justin\Desktop\Project\BB_parks\working_parse_notebook.ipynb Cell 13 in <cell line: 5>()
#       <a href='vscode-notebook-cell:/c%3A/Users/Justin/Desktop/Project/BB_parks/working_parse_notebook.ipynb#X15sZmlsZQ%3D%3D?line=1'>2</a> from tabulate import tabulate
#       <a href='vscode-notebook-cell:/c%3A/Users/Justin/Desktop/Project/BB_parks/working_parse_notebook.ipynb#X15sZmlsZQ%3D%3D?line=3'>4</a> #reads table from pdf file
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Justin/Desktop/Project/BB_parks/working_parse_notebook.ipynb#X15sZmlsZQ%3D%3D?line=4'>5</a> df = read_pdf("data\school_info\HS_enrollment_mhsaa.pdf",pages="all") #address of pdf file
#       <a href='vscode-notebook-cell:/c%3A/Users/Justin/Desktop/Project/BB_parks/working_parse_notebook.ipynb#X15sZmlsZQ%3D%3D?line=5'>6</a> print(tabulate(df))
#
# File c:\Users\Justin\anaconda3\lib\site-packages\tabula\io.py:426, in read_pdf(input_path, output_format, encoding, java_options, pandas_options, multiple_tables, user_agent, use_raw_url, pages, guess, area, relative_area, lattice, stream, password, silent, columns, relative_columns, format, batch, output_path, options)
#     421     raise ValueError(
#     422         "{} is empty. Check the file, or download it manually.".format(path)
#     423     )
#     425 try:
# --> 426     output = _run(java_options, tabula_options, path, encoding)
#     427 finally:
#     428     if temporary:
#
# File c:\Users\Justin\anaconda3\lib\site-packages\tabula\io.py:98, in _run(java_options, options, path, encoding)
#      96     return result.stdout
#      97 except FileNotFoundError:
# ---> 98     raise JavaNotFoundError(JAVA_NOT_FOUND_ERROR)
#      99 except subprocess.CalledProcessError as e:
#     100     logger.error("Error from tabula-java:\n{}\n".format(e.stderr.decode(encoding)))
#
# JavaNotFoundError: `java` command is not found from this Python process.Please ensure Java is installed and PATH is set for `java`

# %%
from shapely import wkt

### Make shapely polygons for each polygon


df['fop_shapely'] = df['fop_wkt'].apply(lambda x: wkt.loads(x))
df['foul_shapely'] = df['foul_wkt'].apply(lambda x: wkt.loads(x))
df.head()
# Out:
# ParseException: Expected number but encountered ','
# ---------------------------------------------------------------------------
# WKTReadingError                           Traceback (most recent call last)
# c:\Users\Justin\Desktop\Project\BB_parks\working_parse_notebook.ipynb Cell 14 in <cell line: 6>()
#       <a href='vscode-notebook-cell:/c%3A/Users/Justin/Desktop/Project/BB_parks/working_parse_notebook.ipynb#X16sZmlsZQ%3D%3D?line=0'>1</a> from shapely import wkt
#       <a href='vscode-notebook-cell:/c%3A/Users/Justin/Desktop/Project/BB_parks/working_parse_notebook.ipynb#X16sZmlsZQ%3D%3D?line=2'>3</a> ### Make shapely polygons for each polygon
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Justin/Desktop/Project/BB_parks/working_parse_notebook.ipynb#X16sZmlsZQ%3D%3D?line=5'>6</a> df['fop_shapely'] = df['fop_wkt'].apply(lambda x: wkt.loads(x))
#       <a href='vscode-notebook-cell:/c%3A/Users/Justin/Desktop/Project/BB_parks/working_parse_notebook.ipynb#X16sZmlsZQ%3D%3D?line=6'>7</a> df['foul_shapely'] = df['foul_wkt'].apply(lambda x: wkt.loads(x))
#       <a href='vscode-notebook-cell:/c%3A/Users/Justin/Desktop/Project/BB_parks/working_parse_notebook.ipynb#X16sZmlsZQ%3D%3D?line=7'>8</a> df.head()
#
# File c:\Users\Justin\anaconda3\lib\site-packages\pandas\core\series.py:4433, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4323 def apply(
#    4324     self,
#    4325     func: AggFuncType,
#    (...)
#    4328     **kwargs,
#    4329 ) -> DataFrame | Series:
#    4330     """
#    4331     Invoke function on values of Series.
#    4332
#    (...)
#    4431     dtype: float64
#    4432     """
# -> 4433     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File c:\Users\Justin\anaconda3\lib\site-packages\pandas\core\apply.py:1082, in SeriesApply.apply(self)
#    1078 if isinstance(self.f, str):
#    1079     # if we are a string, try to dispatch
#    1080     return self.apply_str()
# -> 1082 return self.apply_standard()
#
# File c:\Users\Justin\anaconda3\lib\site-packages\pandas\core\apply.py:1137, in SeriesApply.apply_standard(self)
#    1131         values = obj.astype(object)._values
#    1132         # error: Argument 2 to "map_infer" has incompatible type
#    1133         # "Union[Callable[..., Any], str, List[Union[Callable[..., Any], str]],
#    1134         # Dict[Hashable, Union[Union[Callable[..., Any], str],
#    1135         # List[Union[Callable[..., Any], str]]]]]"; expected
#    1136         # "Callable[[Any], Any]"
# -> 1137         mapped = lib.map_infer(
#    1138             values,
#    1139             f,  # type: ignore[arg-type]
#    1140             convert=self.convert_dtype,
#    1141         )
#    1143 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1144     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1145     #  See also GH#25959 regarding EA support
#    1146     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File c:\Users\Justin\anaconda3\lib\site-packages\pandas\_libs\lib.pyx:2870, in pandas._libs.lib.map_infer()
#
# c:\Users\Justin\Desktop\Project\BB_parks\working_parse_notebook.ipynb Cell 14 in <lambda>(x)
#       <a href='vscode-notebook-cell:/c%3A/Users/Justin/Desktop/Project/BB_parks/working_parse_notebook.ipynb#X16sZmlsZQ%3D%3D?line=0'>1</a> from shapely import wkt
#       <a href='vscode-notebook-cell:/c%3A/Users/Justin/Desktop/Project/BB_parks/working_parse_notebook.ipynb#X16sZmlsZQ%3D%3D?line=2'>3</a> ### Make shapely polygons for each polygon
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Justin/Desktop/Project/BB_parks/working_parse_notebook.ipynb#X16sZmlsZQ%3D%3D?line=5'>6</a> df['fop_shapely'] = df['fop_wkt'].apply(lambda x: wkt.loads(x))
#       <a href='vscode-notebook-cell:/c%3A/Users/Justin/Desktop/Project/BB_parks/working_parse_notebook.ipynb#X16sZmlsZQ%3D%3D?line=6'>7</a> df['foul_shapely'] = df['foul_wkt'].apply(lambda x: wkt.loads(x))
#       <a href='vscode-notebook-cell:/c%3A/Users/Justin/Desktop/Project/BB_parks/working_parse_notebook.ipynb#X16sZmlsZQ%3D%3D?line=7'>8</a> df.head()
#
# File c:\Users\Justin\anaconda3\lib\site-packages\shapely\wkt.py:22, in loads(data)
#       9 def loads(data):
#      10     """
#      11     Load a geometry from a WKT string.
#      12
#    (...)
#      20     Shapely geometry object
#      21     """
# ---> 22     return geos.WKTReader(geos.lgeos).read(data)
#
# File c:\Users\Justin\anaconda3\lib\site-packages\shapely\geos.py:332, in WKTReader.read(self, text)
#     330 geom = self._lgeos.GEOSWKTReader_read(self._reader, c_string)
#     331 if not geom:
# --> 332     raise WKTReadingError(
#     333         "Could not create geometry because of errors "
#     334         "while reading input.")
#     335 # avoid circular import dependency
#     336 from shapely.geometry.base import geom_factory
#
# WKTReadingError: Could not create geometry because of errors while reading input.

# %%
import shapely
from shapely import geometry
from shapely import wkt
from shapely.geometry import Polygon

# poly = geometry.Polygon(df['foul_poly'][1])
# pt = wkt.loads(df['home_lat'][1] + ' ' + df['home_lon'][1])

# # The point is in the polygon, so the distance will always be 0.0
# poly.distance(pt)  # 0.0

# # The distance is calculated to the nearest boundary
# poly.boundary.distance(pt)  # 4.47213595499958

# # or exterior ring
# poly.exterior.distance(pt)  # 4.47213595499958

# %%
# Initializing soup variable
soup = BeautifulSoup(xml_data, 'xml')

folders = soup.Document.Folder
list = soup.Document.Folder.find_all('Folder')
layers = soup.Document.Folder.Folder
polygons = soup.Document.Folder.Placemark.Polygon


print(len(list))
# print(list)

# print(len(folders))
# print(folders)

### 
df = pd.DataFrame(columns=['field_name','foul_coords','fop_coords'])
df

for i in list:

    field_name = layers.find('name').text
    foul = layers.find_all('coordinates')[0].text
    fop = layers.find_all('coordinates')[1].text

    row = {
            'field_name': field_name,
            'foul_coords': foul,
            'fop_coords': fop
        }
        
    df = df.append(row, ignore_index=True)
    # print(f'Appending row %s of %s' % (index+1, items_length))




# print(field_name)
# print(foul)
# print(fop)

# %%
df.head()

# %%
# Initializing soup variable
soup = BeautifulSoup(xml_data, 'xml')

folders = soup.Document.Folder
layers = soup.Document.Folder.Folder.Placemark
polygons = soup.Document.Folder.Placemark.Polygon

# Creating column for table
df = pd.DataFrame(columns=['field', 'foul', 'fop', 'home_plate'])

# Iterating through item tag and extracting elements
f_names = folders.find_all('name')
name_length = len(f_name)

all_coords = soup.find_all('coordinates')
coords_length = len(all_coords)

# print(coords_length)
# print(name_length)
# print(f_names[0:10])
# print(all_coords[0:10])

names_df = pd.DataFrame(f_names)

names_df.to_csv('export_name_list.csv')

# %%
def parse_xml(xml_data):
  # Initializing soup variable
    soup = BeautifulSoup(xml_data, 'xml')
    
    folders = soup.Document.Folder.Folder
    layers = soup.Document.Folder.Folder.Placemark
    polygons = soup.Document.Folder.Placemark.Polygon

  # Creating column for table
    df = pd.DataFrame(columns=['field', 'foul', 'fop', 'home_plate'])

  # Iterating through item tag and extracting elements
    all_items = soup.Folder.find_all('Folder')
    items_length = len(all_items)
    
    for index, item in enumerate(all_items):
        field_name = folders.find('name').text
        foul_coord = polygons.find('coordinates').text
        fop_coords = layers.find('coordinates').find_next('coordinates').contents[0]


       # Adding extracted elements to rows in table
        row = {
            'field': field_name,
            'foul': fop_coords,
            'fop': fop_coords
        }
    

        df = df.append(row, ignore_index=True)
        print(f'Appending row %s of %s' % (index+1, items_length))

    return df

# %%
df = parse_xml(xml_data)
df.to_csv('news.csv')
