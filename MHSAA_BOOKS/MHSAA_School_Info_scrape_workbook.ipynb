# %%
# ## The Goal of this book is to create a table of school information from
# # the Michigan High School Athletic Association (MHSAA) website.

# # This is an example of the URL that we will be scraping:
# examp_url = 'https://my.mhsaa.com/DesktopModules/MHSAA-Endpoint/handlers/SchoolInfo.ashx?method=SchoolDetails&SchoolId=4003'

# # This url retuns a JSON
# # The four digit school ID number is the only thing that changes in the URL.

# # I want to create a dataframe of all of the schools I can find. They will be indexed by SchoolId

# ## This an example of what the jsons will look like:
# {"SchoolId":4003,"SportId":0,"PopularName":"Lansing Catholic","ProperName":"Lansing Catholic HS","NickName":"Cougars","Colors":"Columbia Blue & Silver","LeaugeName":"Capital Area Activities Conference","LeaugeId":6899,"HeadCoach":null,"PrimaryColorCode":"#003366","ImagePath":"mhsaasize/2435.png","Classification":"B","Record":null,"Enrollment":423,"City":"Lansing","State":"MI","Address1":"501 N Marshall","Address2":null,"Zip":"48912","Phone":"(517) 267-2113","Fax":"(517) 267-2135","VanityUrl":"lansingcatholic","MapURL":"https://maps.google.com/maps?q=Lansing Catholic+501 N Marshall++Lansing, MI, 48912","WebSite":"http://www.lansingcatholic.org/","IsMiddleSchool":false,"ClassificationCalculationSteps":[],"ClassificationCalculationStepsHtml":"<table class=\"TabularData\" ><tbody><tr><th width=\"55\">Grade</th><th width=\"35\">Boys</th><th width=\"35\">Girls</th><th width=\"40\">Total</th><th></th></tr><tr><td colspan=\"4\"></td><td rowspan=\"10\" class=\"calculationColumn\">Classification size is 423.</td></tr><tr><td>9</td><td>59</td><td>42</td><td>101</td></tr><tr><td>10</td><td>40</td><td>57</td><td>97</td></tr><tr><td>11</td><td>63</td><td>56</td><td>119</td></tr><tr><td>12</td><td>55</td><td>51</td><td>106</td></tr><tr><td>Other programs draw</td><td>0</td><td>0</td><td>0</td></tr></tbody></table>","SportSeasonId":0,"EnrollmentData":[{"GradeDisplay":"9","GradeTypeCode":9,"BoysCount":59,"GirlsCount":42,"CombinedCount":101},{"GradeDisplay":"10","GradeTypeCode":10,"BoysCount":40,"GirlsCount":57,"CombinedCount":97},{"GradeDisplay":"11","GradeTypeCode":11,"BoysCount":63,"GirlsCount":56,"CombinedCount":119},{"GradeDisplay":"12","GradeTypeCode":12,"BoysCount":55,"GirlsCount":51,"CombinedCount":106},{"GradeDisplay":"Other programs draw","GradeTypeCode":20,"BoysCount":0,"GirlsCount":0,"CombinedCount":0}],"TicketUrl":"https://gofan.co/app/school/MI4125","OldSchoolId":2435,"SchoolNameWithId":"Lansing Catholic (2435)"}


# # I want all of the unique data from each school to be stored
# # I want it all collected into a single dataframe and table that can be saved as a csv

# %%
import requests
import pandas as pd
from tqdm import tqdm
import time
import json

# Start of school IDs
school_id_start = 0000
# End of school IDs
school_id_end = 9999

# Base URL
base_url = 'https://my.mhsaa.com/DesktopModules/MHSAA-Endpoint/handlers/SchoolInfo.ashx?method=SchoolDetails&SchoolId='

# Initialize a timer for the total execution time
total_start_time = time.time()

# Prepare an empty list to store the school data
school_data = []

# Loop over the school IDs
for school_id in tqdm(range(school_id_start, school_id_end+1), desc="Processing Schools"):
    # Build the URL for the current school ID
    url = base_url + str(school_id)
    # Send a GET request to the URL
    response = requests.get(url)
    
    # If the response status code is 200, the request was successful
    if response.status_code == 200:
        # Load the JSON data from the response
        data = json.loads(response.text)
        
        # Check if the data is not empty
        if data:
            # Append the data to the school_data list
            school_data.append(data)
    
    # Pause for a while before sending the next request
    time.sleep(1)

# Convert the list of dictionaries to a DataFrame
df = pd.DataFrame(school_data)

# Print the total execution time
print(f"Total time taken: {int((time.time() - total_start_time)/60)} minutes and {int((time.time() - total_start_time)%60)} seconds")

# # Save the DataFrame to a CSV file
# df.to_csv("school_data.csv", index=False)
# Out:
# Processing Schools: 100%|██████████| 10000/10000 [4:09:29<00:00,  1.50s/it]
# Total time taken: 249 minutes and 29 seconds

# %%
df_raw_backup = df.copy()

# Save the dataframe to a csv
df_raw_backup.to_csv('school_data_scrape_raw.csv', index=False)
df.to_csv('school_data_scrape_READ.csv', index=False)

# %%
#load the csv

df = pd.read_csv('school_data_scrape_READ.csv')

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 32 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   SchoolId                            10000 non-null  int64
#  1   SportId                             10000 non-null  int64
#  2   PopularName                         4049 non-null   object
#  3   ProperName                          4049 non-null   object
#  4   NickName                            922 non-null    object
#  5   Colors                              2105 non-null   object
#  6   LeaugeName                          606 non-null    object
#  7   LeaugeId                            10000 non-null  int64
#  8   HeadCoach                           0 non-null      float64
#  9   PrimaryColorCode                    3117 non-null   object
#  10  ImagePath                           768 non-null    object
#  11  Classification                      737 non-null    object
#  12  Record                              0 non-null      float64
#  13  Enrollment                          10000 non-null  int64
#  14  City                                3982 non-null   object
#  15  State                               3994 non-null   object
#  16  Address1                            2613 non-null   object
#  17  Address2                            205 non-null    object
#  18  Zip                                 2647 non-null   object
#  19  Phone                               2470 non-null   object
#  20  Fax                                 1933 non-null   object
#  21  VanityUrl                           3933 non-null   object
#  22  MapURL                              2517 non-null   object
#  23  WebSite                             1142 non-null   object
#  24  IsMiddleSchool                      10000 non-null  bool
#  25  ClassificationCalculationSteps      737 non-null    object
#  26  ClassificationCalculationStepsHtml  737 non-null    object
#  27  SportSeasonId                       10000 non-null  int64
#  28  EnrollmentData                      737 non-null    object
#  29  TicketUrl                           739 non-null    object
#  30  OldSchoolId                         3997 non-null   float64
#  31  SchoolNameWithId                    4049 non-null   object
# dtypes: bool(1), float64(3), int64(5), object(23)
# memory usage: 2.4+ MB

# %%
## Drop rows without a PopularName
df = df.dropna(subset=['PopularName'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4049 entries, 3834 to 9999
# Data columns (total 32 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   SchoolId                            4049 non-null   int64
#  1   SportId                             4049 non-null   int64
#  2   PopularName                         4049 non-null   object
#  3   ProperName                          4049 non-null   object
#  4   NickName                            922 non-null    object
#  5   Colors                              2104 non-null   object
#  6   LeaugeName                          606 non-null    object
#  7   LeaugeId                            4049 non-null   int64
#  8   HeadCoach                           0 non-null      float64
#  9   PrimaryColorCode                    3117 non-null   object
#  10  ImagePath                           768 non-null    object
#  11  Classification                      737 non-null    object
#  12  Record                              0 non-null      float64
#  13  Enrollment                          4049 non-null   int64
#  14  City                                3982 non-null   object
#  15  State                               3994 non-null   object
#  16  Address1                            2613 non-null   object
#  17  Address2                            205 non-null    object
#  18  Zip                                 2647 non-null   object
#  19  Phone                               2469 non-null   object
#  20  Fax                                 1932 non-null   object
#  21  VanityUrl                           3933 non-null   object
#  22  MapURL                              2517 non-null   object
#  23  WebSite                             1141 non-null   object
#  24  IsMiddleSchool                      4049 non-null   bool
#  25  ClassificationCalculationSteps      737 non-null    object
#  26  ClassificationCalculationStepsHtml  737 non-null    object
#  27  SportSeasonId                       4049 non-null   int64
#  28  EnrollmentData                      737 non-null    object
#  29  TicketUrl                           739 non-null    object
#  30  OldSchoolId                         3997 non-null   float64
#  31  SchoolNameWithId                    4049 non-null   object
# dtypes: bool(1), float64(3), int64(5), object(23)
# memory usage: 1016.2+ KB

# %%
# Create a list of the SchoolId and show the distrobution of the SchoolIds
school_id_list = df['SchoolId'].tolist()
# sort the list
school_id_list.sort()

print(school_id_list)

import matplotlib.pyplot as plt

plt.hist(school_id_list, bins=10)
# Out:
# [3834, 3835, 3836, 3837, 3838, 3839, 3840, 3841, 3842, 3843, 3844, 3845, 3846, 3847, 3848, 3849, 3850, 3851, 3852, 3853, 3854, 3855, 3856, 3857, 3858, 3859, 3860, 3861, 3862, 3863, 3864, 3865, 3866, 3867, 3868, 3869, 3870, 3871, 3872, 3873, 3874, 3875, 3876, 3877, 3878, 3879, 3880, 3881, 3882, 3883, 3884, 3885, 3886, 3887, 3888, 3889, 3890, 3891, 3892, 3893, 3894, 3895, 3896, 3897, 3898, 3899, 3900, 3901, 3902, 3903, 3904, 3905, 3906, 3907, 3908, 3909, 3910, 3911, 3912, 3913, 3914, 3915, 3916, 3917, 3918, 3919, 3920, 3921, 3922, 3923, 3924, 3925, 3926, 3927, 3928, 3929, 3930, 3931, 3932, 3933, 3934, 3935, 3936, 3937, 3938, 3939, 3940, 3941, 3942, 3943, 3944, 3945, 3946, 3947, 3948, 3949, 3950, 3951, 3952, 3953, 3954, 3955, 3956, 3957, 3958, 3959, 3960, 3961, 3962, 3963, 3964, 3965, 3966, 3967, 3968, 3969, 3970, 3971, 3972, 3973, 3974, 3975, 3976, 3977, 3978, 3979, 3980, 3981, 3982, 3983, 3984, 3985, 3986, 3987, 3988, 3989, 3990, 3991, 3992, 3993, 3994, 3995, 3996, 3997, 3998, 3999, 4000, 4001, 4002, 4003, 4004, 4005, 4006, 4007, 4008, 4009, 4010, 4011, 4012, 4013, 4014, 4015, 4016, 4017, 4018, 4019, 4020, 4021, 4022, 4023, 4024, 4025, 4026, 4027, 4028, 4029, 4030, 4031, 4032, 4033, 4034, 4035, 4036, 4037, 4038, 4039, 4040, 4041, 4042, 4043, 4044, 4045, 4046, 4047, 4048, 4049, 4050, 4051, 4052, 4053, 4054, 4055, 4056, 4057, 4058, 4059, 4060, 4061, 4062, 4063, 4064, 4065, 4066, 4067, 4068, 4069, 4070, 4071, 4072, 4073, 4074, 4075, 4076, 4077, 4078, 4079, 4080, 4081, 4082, 4083, 4084, 4085, 4086, 4087, 4088, 4089, 4090, 4091, 4092, 4093, 4094, 4095, 4096, 4097, 4098, 4099, 4100, 4101, 4102, 4103, 4104, 4105, 4106, 4107, 4108, 4109, 4110, 4111, 4112, 4113, 4114, 4115, 4116, 4117, 4118, 4119, 4120, 4121, 4122, 4123, 4124, 4125, 4126, 4127, 4128, 4129, 4130, 4131, 4132, 4133, 4134, 4135, 4136, 4137, 4138, 4139, 4140, 4141, 4142, 4143, 4144, 4145, 4146, 4147, 4148, 4149, 4150, 4151, 4152, 4153, 4154, 4155, 4156, 4157, 4158, 4159, 4160, 4161, 4162, 4163, 4164, 4165, 4166, 4167, 4168, 4169, 4170, 4171, 4172, 4173, 4174, 4175, 4176, 4177, 4178, 4179, 4180, 4181, 4182, 4183, 4184, 4185, 4186, 4187, 4188, 4189, 4190, 4191, 4192, 4193, 4194, 4195, 4196, 4197, 4198, 4199, 4200, 4201, 4202, 4203, 4204, 4205, 4206, 4207, 4208, 4209, 4210, 4211, 4212, 4213, 4214, 4215, 4216, 4217, 4218, 4219, 4220, 4221, 4222, 4223, 4224, 4225, 4226, 4227, 4228, 4229, 4230, 4231, 4232, 4233, 4234, 4235, 4236, 4237, 4238, 4239, 4240, 4241, 4242, 4243, 4244, 4245, 4246, 4247, 4248, 4249, 4250, 4251, 4252, 4253, 4254, 4255, 4256, 4257, 4258, 4259, 4260, 4261, 4262, 4263, 4264, 4265, 4266, 4267, 4268, 4269, 4270, 4271, 4272, 4273, 4274, 4275, 4276, 4277, 4278, 4279, 4280, 4281, 4282, 4283, 4284, 4285, 4286, 4287, 4288, 4289, 4290, 4291, 4292, 4293, 4294, 4295, 4296, 4297, 4298, 4299, 4300, 4301, 4302, 4303, 4304, 4305, 4306, 4307, 4308, 4309, 4310, 4311, 4312, 4313, 4314, 4315, 4316, 4317, 4318, 4319, 4320, 4321, 4322, 4323, 4324, 4325, 4326, 4327, 4328, 4329, 4330, 4331, 4332, 4333, 4334, 4335, 4336, 4337, 4338, 4339, 4340, 4341, 4342, 4343, 4344, 4345, 4346, 4347, 4348, 4349, 4350, 4351, 4352, 4353, 4354, 4355, 4356, 4357, 4358, 4359, 4360, 4361, 4362, 4363, 4364, 4365, 4366, 4367, 4368, 4369, 4370, 4371, 4372, 4373, 4374, 4375, 4376, 4377, 4378, 4379, 4380, 4381, 4382, 4383, 4384, 4385, 4386, 4387, 4388, 4389, 4390, 4391, 4392, 4393, 4394, 4395, 4396, 4397, 4398, 4399, 4400, 4401, 4402, 4403, 4404, 4405, 4406, 4407, 4408, 4409, 4410, 4411, 4412, 4413, 4415, 4416, 4417, 4418, 4419, 4420, 4421, 4422, 4423, 4424, 4425, 4426, 4427, 4428, 4429, 4430, 4431, 4432, 4433, 4434, 4435, 4436, 4437, 4438, 4439, 4440, 4441, 4442, 4443, 4444, 4445, 4446, 4447, 4448, 4449, 4450, 4451, 4452, 4453, 4454, 4455, 4456, 4457, 4458, 4459, 4460, 4461, 4462, 4463, 4464, 4465, 4466, 4467, 4468, 4469, 4470, 4471, 4472, 4473, 4474, 4475, 4476, 4477, 4478, 4479, 4480, 4481, 4482, 4483, 4484, 4485, 4486, 4487, 4488, 4489, 4490, 4491, 4492, 4493, 4494, 4495, 4496, 4497, 4498, 4499, 4500, 450 ...
# (array([616., 603., 574., 608., 592., 130.,   1., 165., 375., 385.]),
#  array([3834. , 4450.5, 5067. , 5683.5, 6300. , 6916.5, 7533. , 8149.5,
#         8766. , 9382.5, 9999. ]),
#  <BarContainer object of 10 artists>)

# %%
# descreibe the schoolid list
# df['SchoolId'].describe()

# Show a sample of the data

# df.sample(10)

# %%
# Drop any records where IsMiddleSchool is true
df = df[df['IsMiddleSchool'] == False]

# Remove the 'IsMiddleSchool' column
df = df.drop(columns=['IsMiddleSchool'])

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2731 entries, 3834 to 9999
# Data columns (total 31 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   SchoolId                            2731 non-null   int64
#  1   SportId                             2731 non-null   int64
#  2   PopularName                         2731 non-null   object
#  3   ProperName                          2731 non-null   object
#  4   NickName                            850 non-null    object
#  5   Colors                              970 non-null    object
#  6   LeaugeName                          606 non-null    object
#  7   LeaugeId                            2731 non-null   int64
#  8   HeadCoach                           0 non-null      float64
#  9   PrimaryColorCode                    2009 non-null   object
#  10  ImagePath                           676 non-null    object
#  11  Classification                      737 non-null    object
#  12  Record                              0 non-null      float64
#  13  Enrollment                          2731 non-null   int64
#  14  City                                2669 non-null   object
#  15  State                               2681 non-null   object
#  16  Address1                            1307 non-null   object
#  17  Address2                            107 non-null    object
#  18  Zip                                 1336 non-null   object
#  19  Phone                               1200 non-null   object
#  20  Fax                                 927 non-null    object
#  21  VanityUrl                           2659 non-null   object
#  22  MapURL                              1522 non-null   object
#  23  WebSite                             854 non-null    object
#  24  ClassificationCalculationSteps      737 non-null    object
#  25  ClassificationCalculationStepsHtml  737 non-null    object
#  26  SportSeasonId                       2731 non-null   int64
#  27  EnrollmentData                      737 non-null    object
#  28  TicketUrl                           739 non-null    object
#  29  OldSchoolId                         2682 non-null   float64
#  30  SchoolNameWithId                    2731 non-null   object
# dtypes: float64(3), int64(5), object(23)
# memory usage: 682.8+ KB

# %%
# Create a list of the SchoolId and show the distrobution of the SchoolIds
school_id_list = df['SchoolId'].tolist()
# sort the list
school_id_list.sort()

print(school_id_list)

import matplotlib.pyplot as plt

plt.hist(school_id_list, bins=10)
# Out:
# [3834, 3835, 3836, 3837, 3838, 3839, 3840, 3841, 3842, 3843, 3844, 3845, 3846, 3847, 3848, 3849, 3850, 3851, 3852, 3853, 3854, 3855, 3856, 3857, 3858, 3859, 3860, 3861, 3862, 3863, 3864, 3865, 3866, 3867, 3868, 3869, 3870, 3871, 3873, 3874, 3875, 3876, 3877, 3878, 3879, 3880, 3881, 3882, 3883, 3884, 3885, 3886, 3887, 3888, 3889, 3890, 3891, 3892, 3893, 3894, 3895, 3896, 3897, 3898, 3899, 3900, 3901, 3902, 3903, 3904, 3905, 3906, 3907, 3908, 3909, 3910, 3911, 3912, 3913, 3914, 3915, 3916, 3917, 3918, 3919, 3920, 3921, 3922, 3923, 3924, 3925, 3926, 3927, 3928, 3929, 3930, 3931, 3932, 3933, 3934, 3935, 3936, 3937, 3938, 3939, 3940, 3941, 3942, 3943, 3944, 3945, 3946, 3947, 3948, 3949, 3950, 3951, 3952, 3953, 3954, 3955, 3956, 3957, 3958, 3959, 3960, 3961, 3962, 3963, 3964, 3965, 3966, 3967, 3968, 3969, 3970, 3971, 3972, 3973, 3974, 3975, 3976, 3977, 3978, 3979, 3980, 3981, 3982, 3983, 3984, 3985, 3986, 3987, 3988, 3989, 3990, 3991, 3992, 3993, 3994, 3995, 3996, 3997, 3998, 3999, 4000, 4001, 4002, 4003, 4004, 4005, 4006, 4007, 4008, 4009, 4010, 4011, 4012, 4013, 4014, 4015, 4016, 4017, 4018, 4019, 4020, 4021, 4022, 4023, 4024, 4025, 4026, 4027, 4028, 4029, 4030, 4031, 4032, 4033, 4034, 4035, 4036, 4037, 4038, 4039, 4040, 4041, 4042, 4043, 4044, 4045, 4046, 4047, 4048, 4049, 4050, 4051, 4052, 4053, 4054, 4055, 4056, 4057, 4058, 4059, 4060, 4061, 4062, 4063, 4064, 4065, 4066, 4067, 4068, 4069, 4070, 4071, 4072, 4073, 4074, 4075, 4076, 4077, 4078, 4079, 4080, 4081, 4082, 4083, 4084, 4085, 4086, 4087, 4088, 4089, 4090, 4091, 4092, 4093, 4094, 4095, 4096, 4097, 4098, 4099, 4100, 4101, 4102, 4103, 4104, 4105, 4106, 4107, 4108, 4109, 4110, 4111, 4112, 4113, 4114, 4115, 4116, 4117, 4118, 4119, 4120, 4121, 4122, 4123, 4124, 4125, 4126, 4127, 4128, 4129, 4130, 4131, 4132, 4133, 4134, 4135, 4136, 4137, 4138, 4139, 4140, 4141, 4142, 4143, 4144, 4145, 4146, 4147, 4148, 4149, 4150, 4151, 4152, 4153, 4154, 4155, 4156, 4157, 4158, 4159, 4160, 4161, 4162, 4163, 4164, 4165, 4166, 4167, 4168, 4169, 4170, 4171, 4172, 4173, 4174, 4175, 4176, 4177, 4178, 4179, 4180, 4181, 4182, 4183, 4184, 4185, 4186, 4187, 4188, 4189, 4190, 4191, 4192, 4193, 4194, 4195, 4196, 4197, 4198, 4199, 4200, 4201, 4202, 4203, 4204, 4205, 4206, 4207, 4208, 4209, 4210, 4211, 4212, 4213, 4214, 4215, 4216, 4217, 4218, 4219, 4220, 4221, 4222, 4223, 4224, 4225, 4226, 4227, 4228, 4229, 4230, 4231, 4232, 4233, 4234, 4235, 4236, 4237, 4238, 4239, 4240, 4241, 4242, 4243, 4244, 4245, 4246, 4247, 4248, 4249, 4250, 4251, 4252, 4253, 4254, 4255, 4256, 4257, 4258, 4259, 4260, 4261, 4262, 4263, 4264, 4265, 4266, 4267, 4268, 4269, 4270, 4271, 4272, 4273, 4274, 4275, 4276, 4277, 4278, 4279, 4280, 4281, 4282, 4283, 4284, 4285, 4286, 4287, 4288, 4289, 4290, 4291, 4292, 4293, 4294, 4295, 4296, 4297, 4298, 4299, 4300, 4301, 4302, 4303, 4304, 4305, 4306, 4307, 4308, 4309, 4310, 4311, 4312, 4313, 4314, 4315, 4316, 4317, 4318, 4319, 4320, 4321, 4322, 4323, 4324, 4325, 4326, 4327, 4328, 4329, 4330, 4331, 4332, 4333, 4334, 4335, 4336, 4337, 4338, 4339, 4340, 4341, 4342, 4343, 4344, 4345, 4346, 4347, 4348, 4349, 4350, 4351, 4352, 4353, 4354, 4355, 4356, 4357, 4358, 4359, 4360, 4361, 4362, 4363, 4364, 4365, 4366, 4367, 4368, 4369, 4370, 4371, 4372, 4373, 4374, 4375, 4376, 4377, 4378, 4379, 4380, 4381, 4382, 4383, 4384, 4385, 4386, 4387, 4388, 4389, 4390, 4391, 4392, 4393, 4394, 4395, 4396, 4397, 4398, 4399, 4400, 4401, 4402, 4403, 4404, 4405, 4406, 4407, 4408, 4409, 4410, 4411, 4412, 4413, 4415, 4416, 4417, 4418, 4419, 4420, 4421, 4422, 4423, 4424, 4425, 4426, 4427, 4428, 4429, 4430, 4431, 4432, 4433, 4434, 4435, 4436, 4437, 4438, 4439, 4440, 4441, 4442, 4443, 4444, 4445, 4446, 4447, 4448, 4449, 4450, 4451, 4452, 4453, 4454, 4455, 4456, 4457, 4458, 4459, 4460, 4461, 4462, 4463, 4464, 4465, 4466, 4467, 4468, 4469, 4470, 4471, 4472, 4473, 4474, 4475, 4476, 4477, 4478, 4479, 4480, 4481, 4482, 4483, 4484, 4485, 4486, 4487, 4488, 4489, 4490, 4491, 4492, 4493, 4494, 4495, 4496, 4497, 4498, 4499, 4500, 4501, 450 ...
# (array([615., 220.,   0., 533., 590.,  57.,   1., 137., 321., 257.]),
#  array([3834. , 4450.5, 5067. , 5683.5, 6300. , 6916.5, 7533. , 8149.5,
#         8766. , 9382.5, 9999. ]),
#  <BarContainer object of 10 artists>)

# %%
df.sample(10)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2731 entries, 3834 to 9999
# Data columns (total 31 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   SchoolId                            2731 non-null   int64
#  1   SportId                             2731 non-null   int64
#  2   PopularName                         2731 non-null   object
#  3   ProperName                          2731 non-null   object
#  4   NickName                            850 non-null    object
#  5   Colors                              970 non-null    object
#  6   LeaugeName                          606 non-null    object
#  7   LeaugeId                            2731 non-null   int64
#  8   HeadCoach                           0 non-null      float64
#  9   PrimaryColorCode                    2009 non-null   object
#  10  ImagePath                           676 non-null    object
#  11  Classification                      737 non-null    object
#  12  Record                              0 non-null      float64
#  13  Enrollment                          2731 non-null   int64
#  14  City                                2669 non-null   object
#  15  State                               2681 non-null   object
#  16  Address1                            1307 non-null   object
#  17  Address2                            107 non-null    object
#  18  Zip                                 1336 non-null   object
#  19  Phone                               1200 non-null   object
#  20  Fax                                 927 non-null    object
#  21  VanityUrl                           2659 non-null   object
#  22  MapURL                              1522 non-null   object
#  23  WebSite                             854 non-null    object
#  24  ClassificationCalculationSteps      737 non-null    object
#  25  ClassificationCalculationStepsHtml  737 non-null    object
#  26  SportSeasonId                       2731 non-null   int64
#  27  EnrollmentData                      737 non-null    object
#  28  TicketUrl                           739 non-null    object
#  29  OldSchoolId                         2682 non-null   float64
#  30  SchoolNameWithId                    2731 non-null   object
# dtypes: float64(3), int64(5), object(23)
# memory usage: 682.8+ KB

# %%
# keep just the rows with State = MI
df = df[df['State'] == 'MI']

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1027 entries, 3834 to 9945
# Data columns (total 31 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   SchoolId                            1027 non-null   int64
#  1   SportId                             1027 non-null   int64
#  2   PopularName                         1027 non-null   object
#  3   ProperName                          1027 non-null   object
#  4   NickName                            819 non-null    object
#  5   Colors                              911 non-null    object
#  6   LeaugeName                          601 non-null    object
#  7   LeaugeId                            1027 non-null   int64
#  8   HeadCoach                           0 non-null      float64
#  9   PrimaryColorCode                    835 non-null    object
#  10  ImagePath                           669 non-null    object
#  11  Classification                      732 non-null    object
#  12  Record                              0 non-null      float64
#  13  Enrollment                          1027 non-null   int64
#  14  City                                1027 non-null   object
#  15  State                               1027 non-null   object
#  16  Address1                            964 non-null    object
#  17  Address2                            90 non-null     object
#  18  Zip                                 984 non-null    object
#  19  Phone                               919 non-null    object
#  20  Fax                                 882 non-null    object
#  21  VanityUrl                           975 non-null    object
#  22  MapURL                              958 non-null    object
#  23  WebSite                             819 non-null    object
#  24  ClassificationCalculationSteps      732 non-null    object
#  25  ClassificationCalculationStepsHtml  732 non-null    object
#  26  SportSeasonId                       1027 non-null   int64
#  27  EnrollmentData                      732 non-null    object
#  28  TicketUrl                           734 non-null    object
#  29  OldSchoolId                         1022 non-null   float64
#  30  SchoolNameWithId                    1027 non-null   object
# dtypes: float64(3), int64(5), object(23)
# memory usage: 256.8+ KB

# %%
## Histogram of the school ids

# Create a list of the SchoolId and show the distrobution of the SchoolIds
school_id_list = df['SchoolId'].tolist()

# sort the list
school_id_list.sort()

import matplotlib.pyplot as plt

plt.hist(school_id_list, bins=10)
# Out:
# (array([607., 224.,   0.,   0.,   0.,  10.,   1.,  15.,  97.,  73.]),
#  array([3834. , 4445.1, 5056.2, 5667.3, 6278.4, 6889.5, 7500.6, 8111.7,
#         8722.8, 9333.9, 9945. ]),
#  <BarContainer object of 10 artists>)

# %%
# Rename ClassificationCalculationSteps to ClassificationNotes
df = df.rename(columns={'ClassificationCalculationSteps': 'ClassificationNotes'})

df.sample(20)
# Out:
#       SchoolId  SportId                     PopularName  \
# 4462      4462        0                LeRoy Pine River
# 3936      3936        0               Lansing Christian
# 4101      4101        0                        Tecumseh
# 4330      4330        0             Wakefield-Marenisco
# 4514      4514        0                          Ashley
# 4015      4015        0                    Byron Center
# 8874      8874        0              Kalamazoo Reformed
# 4477      4477        0                        Portland
# 9492      9492        0   Dearborn Heights WISE Academy
# 3898      3898        0                  Delton Kellogg
# 4189      4189        0        Madison Heights Lamphere
# 4632      4632        0      Jackson Alternative School
# 3922      3922        0                     Boyne Falls
# 3957      3957        0               Ann Arbor Skyline
# 4663      4663        0  Pontiac Academy for Excellence
# 4415      4415        0    Otisville LakeVille Memorial
# 4322      4322        0                       Marcellus
# 9618      9618        0            Unity Knights Hockey
# 4071      4071        0                Utica Eisenhower
# 7347      7347        0  Detroit Frontier International
#
#                               ProperName          NickName  \
# 4462                  Pine River Area HS             Bucks
# 3936                Lansing Christian HS          Pilgrims
# 4101                         Tecumseh HS           Indians
# 4330              Wakefield-Marenisco HS         Cardinals
# 4514                           Ashley HS             Bears
# 4015                     Byron Center HS          Bulldogs
# 8874  Reformed Heritage Chrisitan School         Defenders
# 4477                         Portland HS           Raiders
# 9492                     WISE Academy HS             Lions
# 3898                   Delton Kellogg HS          Panthers
# 4189                         Lamphere HS              Rams
# 4632          Jackson Alternative School               NaN
# 3922                      Boyne Falls HS           Loggers
# 3957                          Skyline HS            Eagles
# 4663      Pontiac Academy for Excellence            Eagles
# 4415               LakeVille Memorial HS           Falcons
# 4322                        Marcellus HS          Wildcats
# 9618                Unity Knights Hockey               NaN
# 4071                 Utica Eisenhower HS            Eagles
# 7347      Frontier International Academy  Frontier Knights
#
#                          Colors                          LeaugeName  LeaugeId  \
# 4462              Green & White                 Highland Conference      6923
# 3936               Black & Gold                                 NaN         0
# 4101             Orange & Black             Southeastern Conference      6979
# 4330             Red/White/Blue          Copper Mountain Conference      9453
# 4514          Royal Blue & Gold     Mid-State Activities Conference      6952
# 4015             Orange & Black                      OK Conference       6963
# 8874              Blue & Orange                                 NaN         0
# 4477       Cardinal Red & White  Capital Area Activities Conference      6899
# 9492           Navy Blue & Gold                                 NaN         0
# 3898             Maroon & White    Southwestern Athletic Conference      6984
# 4189               Blue & White              Macomb Area Conference      6940
# 4632                        NaN                                 NaN         0
# 3922              Green & White                                 NaN         0
# 3957      Columbia Blue & White             Southeastern Conference      6979
# 4663  Burgundy/Gold/Black/White           Charter School Conference      6906
# 4415               Black & Gold                                 NaN         0
# 4322             Orange & Black             Southwest 10 Conference      9489
# 9618                        NaN                                 NaN         0
# 4071      Royal Blue, and White              Macomb Area Conference      6940
# 7347                  Black/Red                                 NaN         0
#
#       HeadCoach PrimaryColorCode  ...                    VanityUrl  \
# 4462        NaN          #003366  ...                    pineriver
# 3936        NaN          #003366  ...             lansingchristian
# 4101        NaN          #003366  ...                     tecumseh
# 4330        NaN          #003366  ...          wakefield-marenisco
# 4514        NaN          #003366  ...                       ashley
# 4015        NaN          #003366  ...                  byroncenter
# 8874        NaN              NaN  ...                          NaN
# 4477        NaN          #003366  ...                     portland
# 9492        NaN              NaN  ...   dearbornheightswiseacademy
# 3898        NaN          #003366  ...                deltonkellogg
# 4189        NaN          #003366  ...                     lamphere
# 4632        NaN          #003366  ...     jacksonalternativeschool
# 3922        NaN          #003366  ...                   boynefalls
# 3957        NaN          #003366  ...                      skyline
# 4663        NaN          #003366  ...  pontiacacademyforexcellence
# 4415        NaN          #003366  ...            lakevillememorial
# 4322        NaN          #003366  ...                    marcellus
# 9618        NaN              NaN  ...                 unityknights
# 4071        NaN          #003366  ...                   eisenhower
# 7347        NaN          #003366  ...        frontierinternational
#
#                                                  MapURL  \
# 4462  https://maps.google.com/maps?q=LeRoy Pine Rive...
# 3936  https://maps.google.com/maps?q=Lansing Christi...
# 4101  https://maps.google.com/maps?q=Tecumseh+760 Br...
# 4330  https://maps.google.com/maps?q=Wakefield-Maren...
# 4514  https://maps.google.com/maps?q=Ashley+104 New ...
# 4015  https://maps.google.com/maps?q=Byron Center+85...
# 8874  https://maps.google.com/maps?q=Kalamazoo Refor...
# 4477  https://maps.google.com/maps?q=Portland+1100 I...
# 9492  https://maps.google.com/maps?q=Dearborn Height...
# 3898  https://maps.google.com/maps?q=Delton Kellogg+...
# 4189  https://maps.google.com/maps?q=Madison Heights...
# 4632                                                NaN
# 3922  https://maps.google.com/maps?q=Boyne Falls+016...
# 3957                            http://goo.gl/maps/HtDm
# 4663  https://maps.google.com/maps?q=Pontiac Academy...
# 4415  https://maps.google.com/maps?q=Otisville LakeV...
# 4322  https://maps.google.com/maps?q=Marcellus+303 W...
# 9618  https://maps.google.com/maps?q=Unity Knights H...
# 4071  https://www.google.com/maps/@42.6987954,-83.05...
# 7347  https://maps.google.com/maps?q=Detroit Frontie...
#
#                                                 WebSite  \
# 4462                         https://www.pineriver.org/
# 3936             http://www.lansingchristianschool.org/
# 4101           http://www.tps.k12.mi.us/index_high.html
# 4330                           http://www.wmschools.org
# 4514            http://www.ashleyschools.net/Sports.htm
# 4015                         http://www.bcpsk12.net/hs/
# 8874                                                NaN
# 4477         http://www.portlandk12.org/departments.htm
# 9492                                                NaN
# 3898              http://www.dkschools.org/?page_id=781
# 4189  http://www.lamphere.k12.mi.us/education/school...
# 4632                                                NaN
# 3922                         http://www.boynefalls.org/
# 3957                         www.aaskylineathletics.com
# 4663                      http://www.pontiacacademy.org
# 4415                    https://lakevilleathletics.org/
# 4322                         http://www.marcelluscs.org
# 9618                                                NaN
# 4071    http://www.macomb.k12.mi.us/utica/ike/index.htm
# 7347                   http://www.frontier-academy.net/
#
#                                     ClassificationNotes  \
# 4462                                                 []
# 3936                                                 []
# 4101                                                 []
# 4330                                                 []
# 4514                                                 []
# 4015                                                 []
# 8874                                                NaN
# 4477                                                 []
# 9492                                                NaN
# 3898                                                 []
# 4189  ['Students who are 19 years of age prior to Se...
# 4632                                                NaN
# 3922                                                 []
# 3957                                                 []
# 4663                                                 []
# 4415                                                 []
# 4322  ['Students who are 19 years of age prior to Se...
# 9618                                                NaN
# 4071                                                 []
# 7347                                                 []
#
#                      ClassificationCalculationStepsHtml SportSeasonId  \
# 4462  <table class="TabularData" ><tbody><tr><th wid...             0
# 3936  <table class="TabularData" ><tbody><tr><th wid...             0
# 4101  <table class="TabularData" ><tbody><tr><th wid...             0
# 4330  <table class="TabularData" ><tbody><tr><th wid...             0
# 4514  <table class="TabularData" ><tbody><tr><th wid...             0
# 4015  <table class="TabularData" ><tbody><tr><th wid...             0
# 8874                                                NaN             0
# 4477  <table class="TabularData" ><tbody><tr><th wid...             0
# 9492                                                NaN             0
# 3898  <table class="TabularData" ><tbody><tr><th wid...             0
# 4189  <table class="TabularData" ><tbody><tr><th wid...             0
# 4632                                                NaN             0
# 3922  <table class="TabularData" ><tbody><tr><th wid...             0
# 3957  <table class="TabularData" ><tbody><tr><th wid...             0
# 4663  <table class="TabularData" ><tbody><tr><th wid...             0
# 4415  <table class="TabularData" ><tbody><tr><th wid...             0
# 4322  <table class="TabularData" ><tbody><tr><th wid...             0
# 9618                                                NaN             0
# 4071  <table class="TabularData" ><tbody><tr><th wid...             0
# 7347  <table class="TabularData" ><tbody><tr><th wid...             0
#
#                                          EnrollmentData  \
# 4462  [{'GradeDisplay': '9', 'GradeTypeCode': 9, 'Bo...
# 3936  [{'GradeDisplay': '9', 'GradeTypeCode': 9, 'Bo...
# 4101  [{'GradeDisplay': '9', 'GradeTypeCode': 9, 'Bo...
# 4330  [{'GradeDisplay': '9', 'GradeTypeCode': 9, 'Bo...
# 4514  [{'GradeDisplay': '9', 'GradeTypeCode': 9, 'Bo...
# 4015  [{'GradeDisplay': '9', 'GradeTypeCode': 9, 'Bo...
# 8874                                                NaN
# 4477  [{'GradeDisplay': '9', 'GradeTypeCode': 9, 'Bo...
# 9492                                                NaN
# 3898  [{'GradeDisplay': '9', 'GradeTypeCode': 9, 'Bo...
# 4189  [{'GradeDisplay': '9', 'GradeTypeCode': 9, 'Bo...
# 4632                                                NaN
# 3922  [{'GradeDisplay': '9', 'GradeTypeCode': 9, 'Bo...
# 3957  [{'GradeDisplay': '9', 'GradeTypeCode': 9, 'Bo...
# 4663  [{'GradeDisplay': '9', 'GradeTypeCode': 9, 'Bo...
# 4415  [{'GradeDisplay': '9', 'GradeTypeCode': 9, 'Bo...
# 4322  [{'GradeDisplay': '9', 'GradeTypeCode': 9, 'Bo...
# 9618                                                NaN
# 4071  [{'GradeDisplay': '9', 'GradeTypeCode': 9, 'Bo...
# 7347  [{'GradeDisplay': '9', 'GradeTypeCode': 9, 'Bo...
#
#                                 TicketUrl OldSchoolId  \
# 4462  https://gofan.co/app/school/MI10364      6956.0
# 3936   https://gofan.co/app/school/MI4449      1858.0
# 4101   https://gofan.co/app/school/MI3685      3350.0
# 4330  https://gofan.co/app/school/MI82752      5545.0
# 4514   https://gofan.co/app/school/MI4035      7500.0
# 4015  https://gofan.co/app/school/MI10135      2542.0
# 8874                                  NaN      1020.0
# 4477  https://gofan.co/app/school/MI10168      7104.0
# 9492                                  NaN      1122.0
# 3898  https://gofan.co/app/school/MI10207      1536.0
# 4189   https://gofan.co/app/school/MI9998      4191.0
# 4632                                  NaN      9461.0
# 3922  https://gofan.co/app/school/MI10306      1734.0
# 3957  https://gofan.co/app/school/MI68101      2032.0
# 4663  https://gofan.co/app/school/MI69759      9927.0
# 4415   https://gofan.co/app/school/MI4445      6460.0
# 4322   https://gofan.co/app/school/MI4499      5446.0
# 9618                                  NaN      1144.0
# 4071  https://gofan.co/app/school/MI10109      3020.0
# 7347  https://gofan.co/app/school/MI69776      9833.0
#
#                            SchoolNameWithId
# 4462                LeRoy Pine River (6956)
# 3936               Lansing Christian (1858)
# 4101                        Tecumseh (3350)
# 4330             Wakefield-Marenisco (5545)
# 4514                          Ashley (7500)
# 4015                    Byron Center (2542)
# 8874              Kalamazoo Reformed (1020)
# 4477                        Portland (7104)
# 9492   Dearborn Heights WISE Academy (1122)
# 3898                  Delton Kellogg (1536)
# 4189        Madison Heights Lamphere (4191)
# 4632      Jackson Alternative School (9461)
# 3922                     Boyne Falls (1734)
# 3957               Ann Arbor Skyline (2032)
# 4663  Pontiac Academy for Excellence (9927)
# 4415    Otisville LakeVille Memorial (6460)
# 4322                       Marcellus (5446)
# 9618            Unity Knights Hockey (1144)
# 4071                Utica Eisenhower (3020)
# 7347  Detroit Frontier International (9833)
#
# [20 rows x 31 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4049 entries, 3834 to 9999
# Data columns (total 32 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   SchoolId                            4049 non-null   int64
#  1   SportId                             4049 non-null   int64
#  2   PopularName                         4049 non-null   object
#  3   ProperName                          4049 non-null   object
#  4   NickName                            922 non-null    object
#  5   Colors                              2104 non-null   object
#  6   LeaugeName                          606 non-null    object
#  7   LeaugeId                            4049 non-null   int64
#  8   HeadCoach                           0 non-null      float64
#  9   PrimaryColorCode                    3117 non-null   object
#  10  ImagePath                           768 non-null    object
#  11  Classification                      737 non-null    object
#  12  Record                              0 non-null      float64
#  13  Enrollment                          4049 non-null   int64
#  14  City                                3982 non-null   object
#  15  State                               3994 non-null   object
#  16  Address1                            2613 non-null   object
#  17  Address2                            205 non-null    object
#  18  Zip                                 2647 non-null   object
#  19  Phone                               2469 non-null   object
#  20  Fax                                 1932 non-null   object
#  21  VanityUrl                           3933 non-null   object
#  22  MapURL                              2517 non-null   object
#  23  WebSite                             1141 non-null   object
#  24  IsMiddleSchool                      4049 non-null   bool
#  25  ClassificationCalculationSteps      737 non-null    object
#  26  ClassificationCalculationStepsHtml  737 non-null    object
#  27  SportSeasonId                       4049 non-null   int64
#  28  EnrollmentData                      737 non-null    object
#  29  TicketUrl                           739 non-null    object
#  30  OldSchoolId                         3997 non-null   float64
#  31  SchoolNameWithId                    4049 non-null   object
# dtypes: bool(1), float64(3), int64(5), object(23)
# memory usage: 1016.2+ KB

# %%
## Save this as MHSAA_School_Data.csv in the clean_tables folder

df.to_csv('TEMP/clean_tables/MHSAA_School_Data.csv', index=False)

# %%
# Show a sample of the data in the ClassificationCalculationStepsHtml column

# df['ClassificationCalculationStepsHtml'].sample(20)

# show a single record of the ClassificationCalculationStepsHtml column so I can tell if I need it
# df['ClassificationCalculationStepsHtml'][3834]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Justin\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File c:\Users\Justin\anaconda3\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\Justin\anaconda3\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:2131, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:2140, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 3834
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# c:\Users\Justin\Desktop\Project\BB_parks\MHSAA_School_Info_scrape_workbook.ipynb Cell 15 in <cell line: 6>()
#       <a href='vscode-notebook-cell:/c%3A/Users/Justin/Desktop/Project/BB_parks/MHSAA_School_Info_scrape_workbook.ipynb#X24sZmlsZQ%3D%3D?line=2'>3</a> df['ClassificationCalculationStepsHtml'].sample(20)
#       <a href='vscode-notebook-cell:/c%3A/Users/Justin/Desktop/Project/BB_parks/MHSAA_School_Info_scrape_workbook.ipynb#X24sZmlsZQ%3D%3D?line=4'>5</a> # show a single record of the ClassificationCalculationStepsHtml column so I can tell if I need it
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Justin/Desktop/Project/BB_parks/MHSAA_School_Info_scrape_workbook.ipynb#X24sZmlsZQ%3D%3D?line=5'>6</a> df['ClassificationCalculationStepsHtml'][3834]
#
# File c:\Users\Justin\anaconda3\lib\site-packages\pandas\core\series.py:958, in Series.__getitem__(self, key)
#     955     return self._values[key]
#     957 elif key_is_scalar:
# --> 958     return self._get_value(key)
#     960 if is_hashable(key):
#     961     # Otherwise index.get_value will raise InvalidIndexError
#     962     try:
#     963         # For labels that don't resolve as scalars like tuples and frozensets
#
# File c:\Users\Justin\anaconda3\lib\site-packages\pandas\core\series.py:1069, in Series._get_value(self, label, takeable)
#    1066     return self._values[label]
#    1068 # Similar to Index.get_value, but we do not fall back to positional
# -> 1069 loc = self.index.get_loc(label)
#    1070 return self.index._get_values_for_loc(self, loc, label)
#
# File c:\Users\Justin\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
# -> 3623     raise KeyError(key) from err
#    3624 except TypeError:
#    3625     # If we have a listlike key, _check_indexing_error will raise
#    3626     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3627     #  the TypeError.
#    3628     self._check_indexing_error(key)
#
# KeyError: 3834

# %%
def parse_html(row):
    try:
        # Parse the HTML content
        soup = BeautifulSoup(row, 'html.parser')
        table = soup.find_all('table')[0] 

        # Convert the table into a DataFrame
        df = pd.read_html(str(table), header=0)[0]

        # Extract the data for the '9', '10', '11', '12', and 'Other programs draw' grades
        grade_9 = df[df['Grade'] == '9'].iloc[0]
        grade_10 = df[df['Grade'] == '10'].iloc[0]
        grade_11 = df[df['Grade'] == '11'].iloc[0]
        grade_12 = df[df['Grade'] == '12'].iloc[0]
        other_programs = df[df['Grade'] == 'Other programs draw'].iloc[0]

        # Return a Series with the extracted data
        return pd.Series([
            grade_9['Boys'], grade_9['Girls'], grade_9['Total'],
            grade_10['Boys'], grade_10['Girls'], grade_10['Total'],
            grade_11['Boys'], grade_11['Girls'], grade_11['Total'],
            grade_12['Boys'], grade_12['Girls'], grade_12['Total'],
            other_programs['Boys'], other_programs['Girls'], other_programs['Total']
        ])
    except:
        # Return None values if the parsing fails
        return pd.Series([None] * 15)

# Apply the function to the column and create new columns for the extracted data
df[['Grade_9_Boys', 'Grade_9_Girls', 'Grade_9_Total',
    'Grade_10_Boys', 'Grade_10_Girls', 'Grade_10_Total',
    'Grade_11_Boys', 'Grade_11_Girls', 'Grade_11_Total',
    'Grade_12_Boys', 'Grade_12_Girls', 'Grade_12_Total',
    'Other_Boys', 'Other_Girls', 'Other_Total']] = df['ClassificationCalculationStepsHtml'].apply(parse_html)

# %%
## Store the cleanedx data in a csv

df.to_csv(f"TEMP/clean_tables/clean_mhsaa_id_scrape.csv", index=False)

# %%
## Create a list of the SchoolId and store it to pass to the next script
school_id_list = df['SchoolId'].tolist()

# %%
## Scrape the MHSAA website using the list of school IDs

# Dependencies

import pandas as pd
import numpy as np
import requests
import json
import re
import time

## Create the 2 functions that perform the parse

# Function to parse game data
def parse_game_data(data, game):
    # Extract the team and league information
    team_name = data["Record"]["TeamName"]
    team_id = data["Record"]["SchoolSportTeamId"]
    league_name = data["League"]["Name"]

    # Extract the opponentId and opponentName
    opponent_id = game["Opponents"][0]["SportTeamId"] if game["Opponents"] else None
    opponent_name = game["Opponents"][0]["PopularName"] if game["Opponents"] else None

    # Extract the gameDate and gameTime
    game_date = game["StartDate"]
    game_time = game["TimeText"]

    # Extract homeOrAway
    home_or_away = game["HomeAwayCode"]

    # Extract location info
    location = game["ContestLocationLink"]

    # Extract teamScore, opponentScore, and notes
    team_score = None
    opponent_score = None
    notes = None
    score_text = game["ScoreText"]
    if score_text:
        # Use regular expression to find scores and notes
        match = re.match(r"(\d+)-(\d+)(.*)", score_text)
        if match:
            team_score, opponent_score, notes = match.groups()
            # Convert scores to integers
            team_score = int(team_score)
            opponent_score = int(opponent_score)
            # Trim whitespace from notes
            notes = notes.strip()

    # Extract additional info
    contest_type = game.get("ContestType")
    season_type = game.get("SeasonType")
    post_season_info = game.get("PostSeasonInfo")
    tournament_info = game.get("TournamentInfo")
    tournament_name = game.get("TournamentName")
    tournament_type = game.get("TournamentType")
    contest_name = game.get("ContestName")
    season_type_code = game.get("SeasonTypeCode")

    return {
        "teamName": team_name,
        "teamId": team_id,
        "leagueName": league_name,
        "opponentName": opponent_name,
        "opponentId": opponent_id,
        "gameDate": game_date,
        "gameTime": game_time,
        "homeOrAway": home_or_away,
        "location": location,
        "teamScore": team_score,
        "opponentScore": opponent_score,
        "notes": notes,
        "contestType": contest_type,
        "seasonType": season_type,
        "postSeasonInfo": post_season_info,
        "tournamentInfo": tournament_info,
        "tournamentName": tournament_name,
        "tournamentType": tournament_type,
        "contestName": contest_name,
        "seasonTypeCode": season_type_code
    }


def initialize_parsing(base_url, school_ids, url_end):
    # Initialize an empty list to hold the parsed data
    parsed_data = []

    # Loop over the school_ids
    for school_id in school_ids:
        # Convert the id to a string
        id_str = str(school_id)
        # Build the URL
        full_url = base_url + id_str + url_end
        # Make the request
        response = requests.get(full_url)

        # Only proceed if the response status code is 200 (HTTP OK)
        if response.status_code == 200:
            # Convert the response to json
            data = response.json()

            # Check to see if the response is valid. If it is, parse the game data
            if 'Contests' in data and data['Contests']:  # Check if 'Contests' key exists and its value is not empty
                for game in data['Contests']:
                    parsed_data.append(parse_game_data(data, game))

    return parsed_data

# %%
import pandas as pd
from tqdm import tqdm
import time
from datetime import datetime

## Target years to scrape
years = [2021, 2020, 2018, 2017,  2016, 2015, 2014, 2013, 2012, 2011, 2010, 2009 ]

## url builder
base_url = 'https://my.mhsaa.com/DesktopModules/MHSAA-Async-SportTeamSchedule/Endpoint.ashx?&method=schedules&orgID='
mid_url = '&sportTypeCode=BA&gender=M&level=V&year='
end_url = '&userid=-1'

# List of Valid school Ids identified above
# school_id_list 

# Initialize a timer for the total execution time
total_start_time = time.time()

# Create a dictionary to store dataframes
df_dict = {}

# Loop over the years
for year in years:
    # Initialize a timer for the year's execution time
    year_start_time = time.time()

    # Initialize the parsing for the given year and team ID range
    parsed_data = initialize_parsing(base_url, school_id_list, mid_url + str(year) + end_url)

    # store the parsed data as DataFrame
    df = pd.DataFrame(parsed_data)

    # Store a copy of the DataFrame in the dictionary
    df_dict[year] = df.copy()
   
    # Generate timestamp
    timestamp = datetime.now().strftime("%Y%m%d%H%M%S")

    # Save the DataFrame to a CSV file in /TEMP/ directory, using year+1 in filename and current timestamp
    df.to_csv(f"TEMP/_{timestamp}_{year+1}.csv", index=False)

    # Print the year's execution time in minutes and seconds
    print(f"Year {year+1} took {int((time.time() - year_start_time)/60)} minutes and {int((time.time() - year_start_time)%60)} seconds")
    
    # print the number of valid records for the year
    # print(f"Number of valid records: {len(df[df['teamName'].notnull()])}")
    # print total number of contests for the year
    print(f"Total number of contests: {len(df)}")

# Print the total execution time
print(f"Total time taken: {int((time.time() - total_start_time)/60)} minutes and {int((time.time() - total_start_time)%60)} seconds")
# Out:
# Year 2022 took 7 minutes and 30 seconds
# Total number of contests: 21119
# Year 2020 took 5 minutes and 59 seconds
# Total number of contests: 12686
# Year 2019 took 7 minutes and 34 seconds
# Total number of contests: 19195
# Year 2018 took 7 minutes and 38 seconds
# Total number of contests: 18198
# Year 2017 took 7 minutes and 24 seconds
# Total number of contests: 18828
# Year 2016 took 6 minutes and 53 seconds
# Total number of contests: 16945
# Year 2015 took 7 minutes and 17 seconds
# Total number of contests: 17967
# Year 2014 took 6 minutes and 53 seconds
# Total number of contests: 17203
# Year 2013 took 6 minutes and 36 seconds
# Total number of contests: 14334
# Year 2012 took 6 minutes and 25 seconds
# Total number of contests: 11902
# Year 2011 took 5 minutes and 52 seconds
# Total number of contests: 7410
# Year 2010 took 5 minutes and 26 seconds
# Total number of contests: 4830
# Total time taken: 81 minutes and 33 seconds

# %%
## Run the same code for a new list of years

year_list = [2022, 2008, 2007, 2006, 2005, 2004, 2003, 2002, 2001, 2000,1999]

## url builder
base_url = 'https://my.mhsaa.com/DesktopModules/MHSAA-Async-SportTeamSchedule/Endpoint.ashx?&method=schedules&orgID='
mid_url = '&sportTypeCode=BA&gender=M&level=V&year='
end_url = '&userid=-1'

# List of Valid school Ids identified above
# school_id_list 

# Initialize a timer for the total execution time
total_start_time = time.time()

# Create a dictionary to store dataframes
df_dict = {}

# Loop over the years
for year in year_list:
    # Initialize a timer for the year's execution time
    year_start_time = time.time()

    # Initialize the parsing for the given year and team ID range
    parsed_data = initialize_parsing(base_url, school_id_list, mid_url + str(year) + end_url)

    # store the parsed data as DataFrame
    df = pd.DataFrame(parsed_data)

    # Store a copy of the DataFrame in the dictionary
    df_dict[year] = df.copy()
   
    # Generate timestamp
    timestamp = datetime.now().strftime("%Y%m%d%H%M%S")

    # Save the DataFrame to a CSV file in /TEMP/ directory, using year+1 in filename and current timestamp
    df.to_csv(f"TEMP/_{timestamp}_{year+1}.csv", index=False)

    # Print the year's execution time in minutes and seconds
    print(f"Year {year+1} took {int((time.time() - year_start_time)/60)} minutes and {int((time.time() - year_start_time)%60)} seconds")
    
    # print the number of valid records for the year
    # print(f"Number of valid records: {len(df[df['teamName'].notnull()])}")
    # print total number of contests for the year
    print(f"Total number of contests: {len(df)}")

# Print the total execution time
print(f"Total time taken: {int((time.time() - total_start_time)/60)} minutes and {int((time.time() - total_start_time)%60)} seconds")
# Out:
# Year 2023 took 7 minutes and 57 seconds
# Total number of contests: 22176
# Year 2009 took 5 minutes and 13 seconds
# Total number of contests: 0
# Year 2008 took 4 minutes and 58 seconds
# Total number of contests: 0
# Year 2007 took 5 minutes and 0 seconds
# Total number of contests: 0
# Year 2006 took 4 minutes and 58 seconds
# Total number of contests: 0
# Year 2005 took 4 minutes and 55 seconds
# Total number of contests: 0
# Year 2004 took 4 minutes and 53 seconds
# Total number of contests: 0
# Year 2003 took 4 minutes and 53 seconds
# Total number of contests: 0
# Year 2002 took 4 minutes and 46 seconds
# Total number of contests: 0
# Year 2001 took 4 minutes and 43 seconds
# Total number of contests: 2
# Year 2000 took 4 minutes and 55 seconds
# Total number of contests: 0
# Total time taken: 57 minutes and 15 seconds

# %%
df.sample(20)
# Out:
#       SchoolId  SportId                            PopularName  \
# 4042      4042        0                        Lansing Eastern
# 8950      8950        0                   Detroit East English
# 4545      4545        0                    Grosse Pointe North
# 4325      4325        0                            Wyoming Lee
# 4426      4426        0                             Grandville
# 3979      3979        0         International Academy of Flint
# 4156      4156        0         Detroit Cleveland Intermediate
# 3915      3915        0                            Centreville
# 9493      9493        0  Grand Rapids Homeschoolers - Spartans
# 3945      3945        0                                 Ecorse
# 9378      9378        0      Battle Creek Bedford Bible School
# 9803      9803        0               Vassar Juniata Christian
# 8303      8303        0               Monroe Meadow Montessori
# 4383      4383        0                              Gladstone
# 3851      3851        0                         Warren Cousino
# 4462      4462        0                       LeRoy Pine River
# 4123      4123        0                               Oak Park
# 4657      4657        0               Eastpointe Eaton Academy
# 4471      4471        0             St Clair Shores Lake Shore
# 8957      8957        0                 Petoskey Homeschoolers
#
#                                  ProperName  NickName                  Colors  \
# 4042                             Eastern HS   Quakers             Blue & Gold
# 8950  East English Village Preparatory Acad  Bulldogs            Maize & Blue
# 4545                 Grosse Pointe North HS  Norsemen            Green & Gold
# 4325                                 Lee HS   Legends  Navy Blue & Vegas Gold
# 4426                          Grandville HS  Bulldogs          Maroon & White
# 3979         International Academy of Flint   Phoenix      Black/Maroon/White
# 4156              Cleveland Intermediate HS   Trojans           Green & White
# 3915                         Centreville HS  Bulldogs             Blue & Gold
# 9493  Grand Rapids Homeschoolers - Spartans       NaN                     NaN
# 3945                              Ecorse HS   Raiders             Red & White
# 9378      Battle Creek Bedford Bible School       NaN                     NaN
# 9803               Vassar Juniata Christian       NaN                     NaN
# 8303                      Meadow Montessori    Wolves       Navy Blue & White
# 4383                           Gladstone HS    Braves          Purple & White
# 3851                             Cousino HS  Patriots          Red/White/Blue
# 4462                     Pine River Area HS     Bucks           Green & White
# 4123                            Oak Park HS   Knights         Red/White/Black
# 4657                          Eaton Academy  Panthers      Royal Blue & White
# 4471                          Lake Shore HS  Shorians             Red & White
# 8957                 Petoskey Homeschoolers       NaN                     NaN
#
#                               LeaugeName  LeaugeId  HeadCoach  \
# 4042  Capital Area Activities Conference      6899        NaN
# 8950       Detroit Public Schools League      6912        NaN
# 4545              Macomb Area Conference      6940        NaN
# 4325                     Alliance League      6894        NaN
# 4426                      OK Conference       6963        NaN
# 3979                                 NaN         0        NaN
# 4156                                 NaN         0        NaN
# 3915             Southwest 10 Conference      9489        NaN
# 9493                                 NaN         0        NaN
# 3945  Michigan Metro Athletic Conference      8890        NaN
# 9378                                 NaN         0        NaN
# 9803                                 NaN         0        NaN
# 8303                                 NaN         0        NaN
# 4383        Great Northern UP Conference      6919        NaN
# 3851              Macomb Area Conference      6940        NaN
# 4462                 Highland Conference      6923        NaN
# 4123      Oakland Activities Association      6962        NaN
# 4657                                 NaN         0        NaN
# 4471              Macomb Area Conference      6940        NaN
# 8957                                 NaN         0        NaN
#
#      PrimaryColorCode  ... Grade_10_Total Grade_11_Boys  Grade_11_Girls  \
# 4042          #003366  ...          246.0          82.0            90.0
# 8950              NaN  ...          208.0         104.0            91.0
# 4545          #003366  ...          287.0         138.0           142.0
# 4325          #003366  ...          129.0          55.0            62.0
# 4426          #003366  ...          443.0         240.0           229.0
# 3979          #003366  ...           61.0          13.0            23.0
# 4156          #003366  ...            NaN           NaN             NaN
# 3915          #003366  ...           74.0          39.0            22.0
# 9493              NaN  ...            NaN           NaN             NaN
# 3945          #003366  ...           69.0          37.0            22.0
# 9378              NaN  ...            NaN           NaN             NaN
# 9803              NaN  ...            NaN           NaN             NaN
# 8303              NaN  ...            NaN           NaN             NaN
# 4383          #003366  ...           97.0          49.0            38.0
# 3851          #003366  ...          364.0         128.0           150.0
# 4462          #003366  ...           78.0          44.0            39.0
# 4123          #003366  ...          259.0         124.0           126.0
# 4657          #003366  ...            NaN           NaN             NaN
# 4471          #003366  ...          237.0         114.0           133.0
# 8957              NaN  ...            NaN           NaN             NaN
#
#       Grade_11_Total Grade_12_Boys Grade_12_Girls Grade_12_Total Other_Boys  \
# 4042           172.0          56.0           62.0          118.0       28.0
# 8950           195.0          72.0           80.0          152.0        0.0
# 4545           280.0         154.0          145.0          299.0        0.0
# 4325           117.0          45.0           38.0           83.0       55.0
# 4426           469.0         225.0          214.0          439.0        0.0
# 3979            36.0          18.0           19.0           37.0        0.0
# 4156             NaN           NaN            NaN            NaN        NaN
# 3915            61.0          41.0           23.0           64.0        0.0
# 9493             NaN           NaN            NaN            NaN        NaN
# 3945            59.0          24.0           22.0           46.0       62.0
# 9378             NaN           NaN            NaN            NaN        NaN
# 9803             NaN           NaN            NaN            NaN        NaN
# 8303             NaN           NaN            NaN            NaN        NaN
# 4383            87.0          52.0           46.0           98.0        0.0
# 3851           278.0         141.0          155.0          296.0        1.0
# 4462            83.0          47.0           35.0           82.0        0.0
# 4123           250.0         113.0          116.0          229.0       94.0
# 4657             NaN           NaN            NaN            NaN        NaN
# 4471           247.0         129.0          119.0          248.0        0.0
# 8957             NaN           NaN            NaN            NaN        NaN
#
#      Other_Girls Other_Total
# 4042        14.0        42.0
# 8950         0.0         0.0
# 4545         0.0         0.0
# 4325        55.0       110.0
# 4426         0.0         0.0
# 3979         0.0         0.0
# 4156         NaN         NaN
# 3915         0.0         0.0
# 9493         NaN         NaN
# 3945        72.0       134.0
# 9378         NaN         NaN
# 9803         NaN         NaN
# 8303         NaN         NaN
# 4383         0.0         0.0
# 3851         1.0         2.0
# 4462         0.0         0.0
# 4123        67.0       161.0
# 4657         NaN         NaN
# 4471         0.0         0.0
# 8957         NaN         NaN
#
# [20 rows x 46 columns]

# %% [markdown]
# ### BREAK

# %%
# # Load raw data from Temp file
# df = pd.read_csv('school_data_scrape.csv')

# df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1001 entries, 0 to 1000
# Data columns (total 32 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   SchoolId                            1001 non-null   int64
#  1   SportId                             1001 non-null   int64
#  2   PopularName                         167 non-null    object
#  3   ProperName                          167 non-null    object
#  4   NickName                            154 non-null    object
#  5   Colors                              166 non-null    object
#  6   LeaugeName                          113 non-null    object
#  7   LeaugeId                            1001 non-null   int64
#  8   HeadCoach                           0 non-null      float64
#  9   PrimaryColorCode                    165 non-null    object
#  10  ImagePath                           134 non-null    object
#  11  Classification                      143 non-null    object
#  12  Record                              0 non-null      float64
#  13  Enrollment                          1001 non-null   int64
#  14  City                                166 non-null    object
#  15  State                               166 non-null    object
#  16  Address1                            165 non-null    object
#  17  Address2                            20 non-null     object
#  18  Zip                                 166 non-null    float64
#  19  Phone                               166 non-null    object
#  20  Fax                                 165 non-null    object
#  21  VanityUrl                           158 non-null    object
#  22  MapURL                              160 non-null    object
#  23  WebSite                             157 non-null    object
#  24  IsMiddleSchool                      1001 non-null   bool
#  25  ClassificationCalculationSteps      143 non-null    object
#  26  ClassificationCalculationStepsHtml  143 non-null    object
#  27  SportSeasonId                       1001 non-null   int64
#  28  EnrollmentData                      143 non-null    object
#  29  TicketUrl                           143 non-null    object
#  30  OldSchoolId                         167 non-null    float64
#  31  SchoolNameWithId                    167 non-null    object
# dtypes: bool(1), float64(4), int64(5), object(22)
# memory usage: 243.5+ KB

# %%
# # Drop the rows with empty data in 'PopularName' column
# df = df.dropna(subset=['PopularName'])

# # Show Length of DataFrame
# print(len(df))
# Out:
# 167
