# %% [markdown]
# ## Notebook to pull all regional sites from the 2022 MHSAA Baseball tournement

# %%
from bs4 import BeautifulSoup
import requests



d1_link = 'https://my.mhsaa.com/Sports/MHSAA-Tournament-Brackets/BracketGroup/9/SportSeasonId/421324/Classification/1'
d2_link = 'https://my.mhsaa.com/Sports/MHSAA-Tournament-Brackets/BracketGroup/9/SportSeasonId/421324/Classification/2'
d3_link = 'https://my.mhsaa.com/Sports/MHSAA-Tournament-Brackets/BracketGroup/9/SportSeasonId/421324/Classification/3'
d4_link = 'https://my.mhsaa.com/Sports/MHSAA-Tournament-Brackets/BracketGroup/9/SportSeasonId/421324/Classification/4'

divs = [d1_link, d2_link, d3_link, d4_link]

# %%
#thirdLevelContests > div > div.contestboxhover > div.contestinfo > span.contestlocation >


# use python and beautiful soup to parse all of the the location names and map links from the span.contestlocation tag in this url https://my.mhsaa.com/Sports/MHSAA-Tournament-Brackets/BracketGroup/9/SportSeasonId/421324/Classification/1

# return the results as a pandas dataframe

import requests
from bs4 import BeautifulSoup
import pandas as pd

i = 4

# Request HTML
url = f'https://my.mhsaa.com/Sports/MHSAA-Tournament-Brackets/BracketGroup/9/SportSeasonId/421324/Classification/{i}'
html = requests.get(url).content

# Parse HTML
soup = BeautifulSoup(html, 'html.parser')

# Find all location tags
locations = soup.find_all('span', {'class': 'contestlocation'})

# Pull out location and map link
data = []
for location in locations:
    loc = location.text.strip()
    link = location.find('a')['href']
    div = 'D'
    data.append([loc, link, div])

# Create DataFrame
df_4 = pd.DataFrame(data, columns=['Location', 'Map Link', 'Division'])

####### DOING IT DIRTY TO JUST GET THE DATA I WANT ########

# %%
df_1
# Out:
#                                              Location  \
# 0        MacDonald Middle School - East Lansing - MAP
# 1             Northville High School - Baseball - MAP
# 2                  Lincoln Baseball - Ypsilanti - MAP
# 3   Coldwater High School (Coldwater @ Borden Fiel...
# 4                       Borden Field  Coldwater - MAP
# 5                       Borden Field  Coldwater - MAP
# 6                       Borden Field  Coldwater - MAP
# 7   James Gulliver Field - Baseball - Allen Park -...
# 8      Stevenson High School - Sterling Heights - MAP
# 9                           Grosse Pointe North - MAP
# 10           Troy Athens High School - Baseball - MAP
# 11  Wayne State University (Baseball Diamond) - De...
# 12  Wayne State University (Baseball Diamond) - De...
# 13  Wayne State University (Baseball Diamond) - De...
# 14                             Saginaw Heritage - MAP
# 15               Portage Northern HS - Baseball - MAP
# 16               Jenison High School - Baseball - MAP
# 17  Cornerstone U. (Baseball Field) - Grand Rapids...
# 18          Mt. Pleasant High School - Baseball - MAP
# 19          Mt. Pleasant High School - Baseball - MAP
# 20          Mt. Pleasant High School - Baseball - MAP
# 21                  Novi High School - Baseball - MAP
# 22                             Joe Pitock Field - MAP
# 23      Rochester High School - Rochester Hills - MAP
# 24                             West Bloomfield  - MAP
# 25                                         Novi - MAP
# 26                                         Novi - MAP
# 27                                         Novi - MAP
#
#                                              Map Link Division
# 0   http://maps.google.com/maps?q=MacDonald+Middle...        A
# 1   http://maps.google.com/maps?q=Northville+High+...        A
# 2   http://maps.google.com/maps?q=Lincoln+Baseball...        A
# 3   http://maps.google.com/maps?q=Coldwater+High+S...        A
# 4   http://maps.google.com/maps?q=Borden+Field++Co...        A
# 5   http://maps.google.com/maps?q=Borden+Field++Co...        A
# 6   http://maps.google.com/maps?q=Borden+Field++Co...        A
# 7   http://maps.google.com/maps?q=James+Gulliver+F...        A
# 8   http://maps.google.com/maps?q=Stevenson+High+S...        A
# 9   http://maps.google.com/maps?q=Grosse+Pointe+No...        A
# 10  http://maps.google.com/maps?q=Troy+Athens+High...        A
# 11  http://maps.google.com/maps?q=Wayne+State+Univ...        A
# 12  http://maps.google.com/maps?q=Wayne+State+Univ...        A
# 13  http://maps.google.com/maps?q=Wayne+State+Univ...        A
# 14  http://maps.google.com/maps?q=Saginaw+Heritage...        A
# 15  http://maps.google.com/maps?q=Portage+Northern...        A
# 16  http://maps.google.com/maps?q=Jenison+High+Sch...        A
# 17  http://maps.google.com/maps?q=Cornerstone+U.+1...        A
# 18  http://maps.google.com/maps?q=Mt.+Pleasant+Hig...        A
# 19  http://maps.google.com/maps?q=Mt.+Pleasant+Hig...        A
# 20  http://maps.google.com/maps?q=Mt.+Pleasant+Hig...        A
# 21  http://maps.google.com/maps?q=Novi+High+School...        A
# 22  http://maps.google.com/maps?q=Joe+Pitock+Field...        A
# 23  http://maps.google.com/maps?q=Rochester+High+S...        A
# 24  http://maps.google.com/maps?q=West+Bloomfield+...        A
# 25  http://maps.google.com/maps?q=Novi+24062+Taft+...        A
# 26  http://maps.google.com/maps?q=Novi+24062+Taft+...        A
# 27  http://maps.google.com/maps?q=Novi+24062+Taft+...        A

# %%
#### Combine all the dataframes into one

df = pd.concat([df_1, df_2, df_3, df_4])

df.info()


# drop duplicates

df.drop_duplicates(inplace=True)
df.info()

# ### Outpu to csv

df.to_csv('data/school_info//regional_locations_all.csv', index=False)

## Working for basic columns, 
## Want to make a column to show the division
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 112 entries, 0 to 27
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Location  112 non-null    object
#  1   Map Link  112 non-null    object
#  2   Division  112 non-null    object
# dtypes: object(3)
# memory usage: 3.5+ KB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 78 entries, 0 to 25
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Location  78 non-null     object
#  1   Map Link  78 non-null     object
#  2   Division  78 non-null     object
# dtypes: object(3)
# memory usage: 2.4+ KB

# %%
#thirdLevelContests > div > div.contestboxhover > div.contestinfo > span.contestlocation


#### Get all the contest locations the page
def get_contest_locations(page):
    soup = BeautifulSoup(page, 'html.parser')
    contest_locations = soup.select('span.contestlocation')
    return contest_locations

# %%
get_contest_locations(d1_link)
print(get_contest_locations(d1_link))
# Out:
# []
# c:\Users\Justin\anaconda3\lib\site-packages\bs4\__init__.py:404: MarkupResemblesLocatorWarning: The input looks more like a URL than markup. You may want to use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   warnings.warn(
